# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта-и-цель" data-toc-modified-id="Описание-проекта-и-цель-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта и цель</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Число-государственных,-частных-и-участковых-(сельских)-больничных-учреждений.-Ресурсы-и-деятельность-организаций-здравоохранения." data-toc-modified-id="Число-государственных,-частных-и-участковых-(сельских)-больничных-учреждений.-Ресурсы-и-деятельность-организаций-здравоохранения.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Число государственных, частных и участковых (сельских) больничных учреждений. Ресурсы и деятельность организаций здравоохранения.</a></span><ul class="toc-item"><li><span><a href="#Предположение" data-toc-modified-id="Предположение-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Предположение</a></span></li><li><span><a href="#Загрузка-и-предобработка-данных" data-toc-modified-id="Загрузка-и-предобработка-данных-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Загрузка и предобработка данных</a></span></li><li><span><a href="#Соединение-в-общий-датасет" data-toc-modified-id="Соединение-в-общий-датасет-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Соединение в общий датасет</a></span></li><li><span><a href="#Создание-датасетов" data-toc-modified-id="Создание-датасетов-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Создание датасетов</a></span><ul class="toc-item"><li><span><a href="#Датасет-с-общими-значениями" data-toc-modified-id="Датасет-с-общими-значениями-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Датасет с общими значениями</a></span></li><li><span><a href="#Датасет-городских-поселений" data-toc-modified-id="Датасет-городских-поселений-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Датасет городских поселений</a></span></li><li><span><a href="#Датасет-сельской-местности" data-toc-modified-id="Датасет-сельской-местности-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Датасет сельской местности</a></span></li></ul></li><li><span><a href="#Транспонирование-ранее-созданных-3-х-датасетов" data-toc-modified-id="Транспонирование-ранее-созданных-3-х-датасетов-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Транспонирование ранее созданных 3-х датасетов</a></span><ul class="toc-item"><li><span><a href="#Транспонированный-датасет-с-общими-значениями" data-toc-modified-id="Транспонированный-датасет-с-общими-значениями-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Транспонированный датасет с общими значениями</a></span></li><li><span><a href="#Транспонированный-датасет-с-городскими-поселениями" data-toc-modified-id="Транспонированный-датасет-с-городскими-поселениями-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Транспонированный датасет с городскими поселениями</a></span></li><li><span><a href="#Транспонированный-датасет-сельской-местности" data-toc-modified-id="Транспонированный-датасет-сельской-местности-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Транспонированный датасет сельской местности</a></span></li></ul></li><li><span><a href="#Сохранение-датасетов-в-csv-файл-для-дальнейшей-визуализации" data-toc-modified-id="Сохранение-датасетов-в-csv-файл-для-дальнейшей-визуализации-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Сохранение датасетов в csv файл для дальнейшей визуализации</a></span></li><li><span><a href="#Ссылка-на-дашборд" data-toc-modified-id="Ссылка-на-дашборд-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ссылка на дашборд</a></span></li><li><span><a href="#Выводы-по-разделу" data-toc-modified-id="Выводы-по-разделу-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Выводы по разделу</a></span></li></ul></li><li><span><a href="#Дома-ребенка.-Ресурсы-и-деятельность-организаций-здравоохранения." data-toc-modified-id="Дома-ребенка.-Ресурсы-и-деятельность-организаций-здравоохранения.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Дома ребенка. Ресурсы и деятельность организаций здравоохранения.</a></span><ul class="toc-item"><li><span><a href="#Предположение" data-toc-modified-id="Предположение-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Предположение</a></span></li><li><span><a href="#Загрузка-и-предобработка-файлов" data-toc-modified-id="Загрузка-и-предобработка-файлов-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Загрузка и предобработка файлов</a></span></li><li><span><a href="#Соединяем-данные-из-всех-папок-в-один-датафрейм" data-toc-modified-id="Соединяем-данные-из-всех-папок-в-один-датафрейм-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Соединяем данные из всех папок в один датафрейм</a></span></li><li><span><a href="#Ссылка-на-дашборд" data-toc-modified-id="Ссылка-на-дашборд-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Ссылка на дашборд</a></span></li><li><span><a href="#Выводы-по-разделу" data-toc-modified-id="Выводы-по-разделу-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Выводы по разделу</a></span></li></ul></li><li><span><a href="#Коечный-фонд-по-специализации-в-Субъектах-Российской-Федерации.-Ресурсы-и-деятельность-организаций-здравоохранения." data-toc-modified-id="Коечный-фонд-по-специализации-в-Субъектах-Российской-Федерации.-Ресурсы-и-деятельность-организаций-здравоохранения.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Коечный фонд по специализации в Субъектах Российской Федерации. Ресурсы и деятельность организаций здравоохранения.</a></span><ul class="toc-item"><li><span><a href="#Предположение" data-toc-modified-id="Предположение-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Предположение</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Данные-из-папки-за-2005-год" data-toc-modified-id="Данные-из-папки-за-2005-год-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Данные из папки за 2005 год</a></span></li><li><span><a href="#Данные-из-папки-2007-года" data-toc-modified-id="Данные-из-папки-2007-года-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Данные из папки 2007 года</a></span></li><li><span><a href="#Данные-из-папки-2009-года" data-toc-modified-id="Данные-из-папки-2009-года-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Данные из папки 2009 года</a></span></li><li><span><a href="#Данные-из-папки-за-2011-год" data-toc-modified-id="Данные-из-папки-за-2011-год-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Данные из папки за 2011 год</a></span></li><li><span><a href="#Данные-из-папки-за-2013-год" data-toc-modified-id="Данные-из-папки-за-2013-год-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Данные из папки за 2013 год</a></span></li></ul></li><li><span><a href="#Сохранение-данных" data-toc-modified-id="Сохранение-данных-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Сохранение данных</a></span></li><li><span><a href="#Дополнительное-соединение-и-сохранение-датасета" data-toc-modified-id="Дополнительное-соединение-и-сохранение-датасета-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Дополнительное соединение и сохранение датасета</a></span></li><li><span><a href="#Ссылка-на-дашборд" data-toc-modified-id="Ссылка-на-дашборд-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Ссылка на дашборд</a></span></li><li><span><a href="#Выводы-по-разделу" data-toc-modified-id="Выводы-по-разделу-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Выводы по разделу</a></span></li></ul></li><li><span><a href="#Техническое-состояние-и-благоустройство-зданий-лечебно-профилактических-учреждений-здравоохранения.-Ресурсы-и-деятельность-организаций-здравоохранения." data-toc-modified-id="Техническое-состояние-и-благоустройство-зданий-лечебно-профилактических-учреждений-здравоохранения.-Ресурсы-и-деятельность-организаций-здравоохранения.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Техническое состояние и благоустройство зданий лечебно-профилактических учреждений здравоохранения. Ресурсы и деятельность организаций здравоохранения.</a></span><ul class="toc-item"><li><span><a href="#Предположение" data-toc-modified-id="Предположение-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Предположение</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Соединение-в-единый-датасет" data-toc-modified-id="Соединение-в-единый-датасет-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Соединение в единый датасет</a></span></li><li><span><a href="#Сохранение-получившихся-датасетов-и-разделение-их-на-стационар-и-амбулатории" data-toc-modified-id="Сохранение-получившихся-датасетов-и-разделение-их-на-стационар-и-амбулатории-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Сохранение получившихся датасетов и разделение их на стационар и амбулатории</a></span></li><li><span><a href="#Ссылка-на-дашборд" data-toc-modified-id="Ссылка-на-дашборд-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Ссылка на дашборд</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Вывод по разделу</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Визуализация медицинской статистики по данным [Росстата](https://rosstat.gov.ru/folder/210/document/13218)

# %% [markdown]
# ## Описание проекта и цель

# %% [markdown]
# **Выполнил Данилов Евгений**
#
# Целью проекта является изучение данных сайта Росстата, которые были получены путём парсинга, с дальнейшей визуализацией полученных результатов в виде дашбордов.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Раздел сайта [Здравоохранение в России](https://rosstat.gov.ru/folder/210/document/13218) содержит сборник данных.
# При подготовке сборника использованы данные, получаемые органами государственной статистики от юридических лиц, населения путем проведения федерального статистического наблюдения, выборочных обследований и других форм статистического наблюдения, данные министерств и ведомств Российской Федерации.
# В сборнике публикуются сведения о медико-демографических аспектах здоровья населения и его отдельных социально-демографических групп, организации лечебно-профилактической помощи и санаторно-курортного лечения населения, а также о состоянии рынка труда в здравоохранении, производстве товаров медицинского назначения, потребительском рынке товаров и услуг здравоохранения. Приведена информация о состоянии окружающей среды и санитарно-эпидемиологическом контроле.
# Статистические данные в разрезе субъектов Российской Федерации начиная с 2015 года выделены в отдельное электронное приложение. Сборник издается начиная с 2001 года с периодичностью один раз в два года, с 2015 года – только в электронном виде.
# В данном проекте делаем дашборды по подразделу **Ресурсы и деятельность организаций здравоохранения**, который имеется в сборнике данных

# %% [markdown]
# ## Загрузка библиотек

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Число государственных, частных и участковых (сельских) больничных учреждений. Ресурсы и деятельность организаций здравоохранения.

# %% [markdown]
# ### Предположение

# %% [markdown]
# За период 1990 - 2022 число государственных больничных организаций снизилось на 20%, число частных больничных организаций выросло в 4 раза, а количество участковых (сельских) больниц уменьшилось в 20 раз.

# %% [markdown]
# ### Загрузка и предобработка данных

# %%
hospital_facilities_2005 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2005/Ресурсы и деятельность учреждений здравоохранения/больничные учреждения.csv')

hospital_facilities_2005.columns = hospital_facilities_2005.iloc[0]

hospital_facilities_2005.rename(columns = {np.nan:'name'}, inplace=True)

hospital_facilities_2005 = hospital_facilities_2005.drop(index = [0, 1]).reset_index(drop=True)

hospital_facilities_2005.head()
# Out:
# 0                                    name    1990    1995    2000    2001  \
# 0             Число больничных учреждений   12762   12064   10704   10561
# 1                из них негосударственные     ...      29      87     105
# 2    Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 3                             всего, тыс.  2037.6  1850.5  1671.6  1653.4
# 4  из них в негосударственных учреждениях     ...     2.5     7.7     7.9
#
# 0    2002    2003    2004
# 0   10320   10101    9851
# 1      97     111     122
# 2     NaN     NaN     NaN
# 3  1619.7  1596.6  1600.7
# 4     7.8     7.9     9.8

# %% [markdown]
# Посмотрим на уникальные названия колонки name, так как после изучения каждой таблицы "больничные учреждения" из каждой папки по годам, будем всё это соединять в единую таблицу по колонкам. Колонка name может содержать неодинаковые (неунифицированные) названия

# %%
hospital_facilities_2005['name'].unique()
# Out:
# array(['Число больничных учреждений', 'из них негосударственные',
#        'Число коек в больничных учреждениях:', 'всего, тыс.',
#        'из них в негосударственных учреждениях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan,
#        'Число центральных районних больниц'], dtype=object)

# %%
hospital_facilities_2007 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2007/Ресурсы и деятельность учреждений здравоохранения/больничные учреждения.csv')

hospital_facilities_2007.columns = hospital_facilities_2007.iloc[0]

hospital_facilities_2007.rename(columns = {np.nan:'name'}, inplace=True)

hospital_facilities_2007 = hospital_facilities_2007.drop(index = [0, 1]).reset_index(drop=True)

hospital_facilities_2007.head()
# Out:
# 0                                  name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
# 0    2006
# 0    7478
# 1     320
# 2     148
# 3     NaN
# 4  1553.6

# %%
hospital_facilities_2007['name'].unique()
# Out:
# array(['Число больничных учреждений', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных учреждениях:', 'всего, тыс.',
#        'из них в негосударственных  учреждениях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной  больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan,
#        'из них частной формы  собственности'], dtype=object)

# %%
hospital_facilities_2009 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2009/Ресурсы и деятельность учреждений здравоохранения/больничные учреждения.csv')

hospital_facilities_2009.columns = hospital_facilities_2009.iloc[0]

hospital_facilities_2009.rename(columns = {np.nan:'name'}, inplace=True)

hospital_facilities_2009 = hospital_facilities_2009.drop(index = [0, 1]).reset_index(drop=True)

hospital_facilities_2009.head()
# Out:
# 0                                  name    1995    2000    2005    2007  \
# 0           Число больничных учреждений   12064   10704    9479    6777
# 1              из них негосударственные      29      87     293     333
# 2   из них частной формы  собственности     ...     ...     ...     177
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  1850.5  1671.6  1575.4  1522.1
#
# 0     2008
# 0     6545
# 1      253
# 2      120
# 3      NaN
# 4  1398,52

# %%
hospital_facilities_2009['name'].unique()
# Out:
# array(['Число больничных учреждений', 'из них негосударственные',
#        'из них частной формы  собственности',
#        'Число коек в больничных учреждениях:', 'всего, тыс.',
#        'из них в негосударственных  учреждениях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной  больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %%
hospital_facilities_2011 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2011/Ресурсы и деятельность учреждений здравоохранения/больничные учреждения.csv')

hospital_facilities_2011.columns = hospital_facilities_2011.iloc[0]

hospital_facilities_2011.rename(columns = {np.nan:'name'}, inplace=True)

hospital_facilities_2011 = hospital_facilities_2011.drop(index = [0, 1]).reset_index(drop=True)

hospital_facilities_2011.head()
# Out:
# 0                                  name    1995    2000    2005    2009  \
# 0           Число больничных учреждений   12064   10704    9479    6454
# 1              из них негосударственные      29      87     293     224
# 2    из них частной формы собственности       -       -     ...     107
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  1850.5  1671.6  1575.4  1373.4
#
# 0    2010
# 0    6308
# 1     224
# 2     115
# 3     NaN
# 4  1339.5

# %%
hospital_facilities_2011['name'].unique()
# Out:
# array(['Число больничных учреждений', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных учреждениях:', 'всего, тыс.',
#        'из них в негосударственных учреждениях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %%
hospital_facilities_2013 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2013/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.1. больничные организации.csv')

hospital_facilities_2013 = hospital_facilities_2013.drop(index = [0]).reset_index(drop=True)

hospital_facilities_2013.rename(columns = {'Unnamed: 0':'name'}, inplace=True)

hospital_facilities_2013.head()
# Out:
#                                     name    2000    2005     2010     2011  \
# 0           Число больничных организаций   10704    9479     6308     6343
# 1               из них негосударственные      87     293      224      220
# 2     из них частной формы собственности       -       …      115      116
# 3  Число коек в больничных организациях:     NaN     NaN      NaN      NaN
# 4                            всего, тыс.  1671,6  1575,4  1339,51  1347,11
#
#       2012
# 0     6172
# 1      225
# 2      127
# 3      NaN
# 4  1332,31

# %%
hospital_facilities_2013['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %%
hospital_facilities_2011['name'].unique() == hospital_facilities_2013['name'].unique()
# Out:
# array([False,  True,  True, False,  True, False,  True,  True,  True,
#         True,  True,  True, False])

# %%
print(hospital_facilities_2011['name'][[0, 3, 5]])

print('-'*50)

print(hospital_facilities_2013['name'][[0, 3, 5]])
# Out:
# 0               Число больничных учреждений
# 3      Число коек в больничных учреждениях:
# 5    из них в негосударственных учреждениях
# Name: name, dtype: object
# --------------------------------------------------
# 0               Число больничных организаций
# 3      Число коек в больничных организациях:
# 5    из них в негосударственных организациях
# Name: name, dtype: object

# %% [markdown]
# При сравнению с названиями колонки name 2011 года с 2013 есть несовпадающие значения. Видно, что слово "учреждения" изменили на "организации".

# %% [markdown]
# Создадим новую переменную `res` в которой будет словарь со старыми значениями из строк колонки "name" 2013 года и новые значения из строк колонки "name" 2011 года.

# %%
res = {list(hospital_facilities_2013['name'])[i]: list(hospital_facilities_2011['name'])[i] for i in range(len(list(hospital_facilities_2013['name'])))}

res
# Out:
# {'Число больничных организаций': 'Число больничных учреждений',
#  'из них негосударственные': 'из них негосударственные',
#  'из них частной формы собственности': 'из них частной формы собственности',
#  'Число коек в больничных организациях:': 'Число коек в больничных учреждениях:',
#  'всего, тыс.': 'всего, тыс.',
#  'из них в негосударственных организациях': 'из них в негосударственных учреждениях',
#  'на 10 000 человек населения': 'на 10 000 человек населения',
#  'Число центральных районных больниц': 'Число центральных районных больниц',
#  'в них коек, тыс.': 'в них коек, тыс.',
#  'средняя мощность одной больницы, коек': 'средняя мощность одной больницы, коек',
#  'Число районных больниц': 'Число районных больниц',
#  'Число участковых больниц': 'Число участковых больниц',
#  nan: nan}

# %%
hospital_facilities_2013['name'] = hospital_facilities_2013['name'].map(res)

hospital_facilities_2013['name']
# Out:
# 0                Число больничных учреждений
# 1                   из них негосударственные
# 2         из них частной формы собственности
# 3       Число коек в больничных учреждениях:
# 4                                всего, тыс.
# 5     из них в негосударственных учреждениях
# 6         из них частной формы собственности
# 7                на 10 000 человек населения
# 8         Число центральных районных больниц
# 9                           в них коек, тыс.
# 10     средняя мощность одной больницы, коек
# 11                    Число районных больниц
# 12                          в них коек, тыс.
# 13     средняя мощность одной больницы, коек
# 14                  Число участковых больниц
# 15                          в них коек, тыс.
# 16     средняя мощность одной больницы, коек
# 17                                       NaN
# 18               Число больничных учреждений
# 19                  из них негосударственные
# 20        из них частной формы собственности
# ...

# %%
hospital_facilities_2015 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2015/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.1. больничные организации.csv')

hospital_facilities_2015 = hospital_facilities_2015.drop(index = [0]).reset_index(drop=True)

hospital_facilities_2015.rename(columns = {'Unnamed: 0':'name'}, inplace=True)

hospital_facilities_2015.head()
# Out:
#                                     name    2005     2010     2011     2012  \
# 0           Число больничных организаций    9479     6308     6343     6172
# 1               из них негосударственные     293      224      220      225
# 2     из них частной формы собственности       …      115      116      127
# 3  Число коек в больничных организациях:     NaN      NaN      NaN      NaN
# 4                            всего, тыс.  1575,4  1339,51  1347,11  1332,31
#
#       2013     2014
# 0     5870     5638
# 1      233      246
# 2      143      166
# 3      NaN      NaN
# 4  1301,91  1266,81

# %%
hospital_facilities_2015['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %% [markdown]
# В 2015 году также видно, что слово "учреждения" заменили на "организации", восплользуемся ранее созданным словарём из переменной `res` и изменим названия для унификации.

# %%
hospital_facilities_2015['name'] = hospital_facilities_2015['name'].map(res)

hospital_facilities_2015['name']
# Out:
# 0                Число больничных учреждений
# 1                   из них негосударственные
# 2         из них частной формы собственности
# 3       Число коек в больничных учреждениях:
# 4                                всего, тыс.
# 5     из них в негосударственных учреждениях
# 6         из них частной формы собственности
# 7                на 10 000 человек населения
# 8         Число центральных районных больниц
# 9                           в них коек, тыс.
# 10     средняя мощность одной больницы, коек
# 11                    Число районных больниц
# 12                          в них коек, тыс.
# 13     средняя мощность одной больницы, коек
# 14                  Число участковых больниц
# 15                          в них коек, тыс.
# 16     средняя мощность одной больницы, коек
# 17                                       NaN
# 18               Число больничных учреждений
# 19                  из них негосударственные
# 20        из них частной формы собственности
# ...

# %%
hospital_facilities_2017 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2017/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.1. больничные организации.csv')

hospital_facilities_2017 = hospital_facilities_2017.drop(index = [0]).reset_index(drop=True)

hospital_facilities_2017.rename(columns = {'Unnamed: 0':'name'}, inplace=True)

hospital_facilities_2017.head()
# Out:
#                                     name    2005     2010     2013     2014  \
# 0           Число больничных организаций    9479     6308     5870     5638
# 1               из них негосударственные     293      224      233      246
# 2     из них частной формы собственности       …      115      143      166
# 3  Число коек в больничных организациях:     NaN      NaN      NaN      NaN
# 4                            всего, тыс.  1575,4  1339,51  1301,91  1266,81
#
#      2015    2016
# 0    5433    5357
# 1     245     266
# 2     180     205
# 3     NaN     NaN
# 4  1222,0  1197,2

# %%
hospital_facilities_2017['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %% [markdown]
# Изменим названия строк колонки name 2017 с применением ранее созданного словаря в переменной `res`

# %%
hospital_facilities_2017['name'] = hospital_facilities_2017['name'].map(res)

# %%
hospital_facilities_2017
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                    9479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                    1734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2019 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2019/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.1. больничные организации.csv')

hospital_facilities_2019 = hospital_facilities_2019.drop(index = [0]).reset_index(drop=True)

hospital_facilities_2019.rename(columns = {'Unnamed: 0':'name'}, inplace=True)

hospital_facilities_2019.head()
# Out:
#                                     name    2005     2010     2015     2016  \
# 0           Число больничных организаций    9479     6308     5433     5357
# 1               из них негосударственные     293      224      245      266
# 2     из них частной формы собственности       …      115      180      205
# 3  Число коек в больничных организациях:     NaN      NaN      NaN      NaN
# 4                            всего, тыс.  1575,4  1339,51  1222,01  1197,21
#
#       2017     2018
# 0     5293     5257
# 1      294      319
# 2      241      259
# 3      NaN      NaN
# 4  1182,71  1172,81

# %%
hospital_facilities_2019['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %% [markdown]
# Изменим названия строк колонки name папки 2019 года с применением ранее созданного словаря в переменной `res`

# %%
hospital_facilities_2019['name'] = hospital_facilities_2019['name'].map(res)

# %%
hospital_facilities_2019
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                    9479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                    1734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2021 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2021/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.1. больничные организации.csv')

hospital_facilities_2021 = hospital_facilities_2021.drop(index = [0]).reset_index(drop=True)

hospital_facilities_2021.rename(columns = {'Unnamed: 0':'name'}, inplace=True)

hospital_facilities_2021.head()
# Out:
#                                     name     2005      2010      2015  \
# 0           Число больничных организаций    9 479     6 308     5 433
# 1               из них негосударственные      293       224       245
# 2     из них частной формы собственности        …       115       180
# 3  Число коек в больничных организациях:      NaN       NaN       NaN
# 4                            всего, тыс.  1 575,4  1 339,51  1 222,01
#
#        2018      2019      2020
# 0     5 257     5 130     5 065
# 1       319       328       344
# 2       259       274       294
# 3       NaN       NaN       NaN
# 4  1 172,81  1 173,61  1 188,81

# %%
hospital_facilities_2021['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %%
hospital_facilities_2021['name'] = hospital_facilities_2021['name'].map(res)

# %%
hospital_facilities_2021
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                   9 479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                 1 575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                   1 734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2023 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2023/БОЛЬНИЧНЫЕ ОРГАНИЗАЦИИ - 3.1.csv')

hospital_facilities_2023.columns = hospital_facilities_2023.iloc[0]

hospital_facilities_2023 = hospital_facilities_2023.drop(index = [0, 1]).reset_index(drop=True)

hospital_facilities_2023.rename(columns = {np.nan:'name'}, inplace=True)

hospital_facilities_2023.head()
# Out:
# 0                                   name      2010      2015      2019  \
# 0           Число больничных организаций     6 308     5 433     5 130
# 1               из них негосударственные       224       245       328
# 2     из них частной формы собственности       115       180       274
# 3  Число коек в больничных организациях:       NaN       NaN       NaN
# 4                            всего, тыс.  1 339,51  1 222,01  1 173,61
#
# 0      2020      2021       2022
# 0     5 065     5 072      5 167
# 1       344       410        458
# 2       294       367        409
# 3       NaN       NaN        NaN
# 4  1 188,81  1 162,11   1 141,91

# %%
hospital_facilities_2023['name'].unique()
# Out:
# array(['Число больничных организаций', 'из них негосударственные',
#        'из них частной формы собственности',
#        'Число коек в больничных организациях:', 'всего, тыс.',
#        'из них в негосударственных организациях',
#        'на 10 000 человек населения',
#        'Число центральных районных больниц', 'в них коек, тыс.',
#        'средняя мощность одной больницы, коек', 'Число районных больниц',
#        'Число участковых больниц', nan], dtype=object)

# %%
hospital_facilities_2023['name'] = hospital_facilities_2023['name'].map(res)

hospital_facilities_2023
# Out:
# 0                                     name                    2010      2015  \
# 0              Число больничных учреждений                   6 308     5 433
# 1                 из них негосударственные                     224       245
# 2       из них частной формы собственности                     115       180
# 3     Число коек в больничных учреждениях:                     NaN       NaN
# 4                              всего, тыс.                1 339,51  1 222,01
# 5   из них в негосударственных учреждениях                    21,7      24,1
# 6       из них частной формы собственности                     4,1      12,8
# 7              на 10 000 человек населения                    93,8      83,4
# 8       Число центральных районных больниц                   1 754     1 426
# 9                         в них коек, тыс.                   327,1     205,6
# 10   средняя мощность одной больницы, коек                     186       144
# ...

# %%
hospital_facilities_2005
# Out:
# 0                                     name                    1990  \
# 0              Число больничных учреждений                   12762
# 1                 из них негосударственные                     ...
# 2     Число коек в больничных учреждениях:                     NaN
# 3                              всего, тыс.                  2037.6
# 4   из них в негосударственных учреждениях                     ...
# 5              на 10 000 человек населения                   137.4
# 6       Число центральных районных больниц                    1798
# 7                         в них коек, тыс.                   451.0
# 8    средняя мощность одной больницы, коек                     251
# 9                   Число районных больниц                     324
# 10                        в них коек, тыс.                    33.8
# 11   средняя мощность одной больницы, коек                     104
# 12                Число участковых больниц                    4813
# ...

# %%
hospital_facilities_2007
# Out:
# 0                                      name                    1990  \
# 0               Число больничных учреждений                   12762
# 1                  из них негосударственные                     ...
# 2        из них частной формы собственности                     ...
# 3      Число коек в больничных учреждениях:                     NaN
# 4                               всего, тыс.                  2037.6
# 5   из них в негосударственных  учреждениях                     ...
# 6        из них частной формы собственности                     ...
# 7               на 10 000 человек населения                   137.4
# 8        Число центральных районных больниц                    1798
# 9                          в них коек, тыс.                   451.0
# 10   средняя мощность одной  больницы, коек                     251
# 11                   Число районных больниц                     324
# 12                         в них коек, тыс.                    33.8
# ...

# %%
hospital_facilities_2009
# Out:
# 0                                      name                    1995  \
# 0               Число больничных учреждений                   12064
# 1                  из них негосударственные                      29
# 2       из них частной формы  собственности                     ...
# 3      Число коек в больничных учреждениях:                     NaN
# 4                               всего, тыс.                  1850.5
# 5   из них в негосударственных  учреждениях                     2.5
# 6       из них частной формы  собственности                     ...
# 7               на 10 000 человек населения                   125.8
# 8        Число центральных районных больниц                    1786
# 9                          в них коек, тыс.                   409.7
# 10   средняя мощность одной  больницы, коек                     229
# 11                   Число районных больниц                     294
# 12                         в них коек, тыс.                    31.6
# ...

# %%
hospital_facilities_2011
# Out:
# 0                                     name                    1995  \
# 0              Число больничных учреждений                   12064
# 1                 из них негосударственные                      29
# 2       из них частной формы собственности                       -
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1850.5
# 5   из них в негосударственных учреждениях                     2.5
# 6       из них частной формы собственности                       -
# 7              на 10 000 человек населения                   125.8
# 8       Число центральных районных больниц                    1786
# 9                         в них коек, тыс.                   409.7
# 10   средняя мощность одной больницы, коек                     229
# 11                  Число районных больниц                     294
# 12                        в них коек, тыс.                    31.6
# ...

# %%
hospital_facilities_2013
# Out:
#                                       name                    2000  \
# 0              Число больничных учреждений                   10704
# 1                 из них негосударственные                      87
# 2       из них частной формы собственности                       -
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1671,6
# 5   из них в негосударственных учреждениях                     7,7
# 6       из них частной формы собственности                       -
# 7              на 10 000 человек населения                   115,0
# 8       Число центральных районных больниц                    1765
# 9                         в них коек, тыс.                   373,6
# 10   средняя мощность одной больницы, коек                     211
# 11                  Число районных больниц                     263
# 12                        в них коек, тыс.                    28,4
# ...

# %%
hospital_facilities_2015
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                    9479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                    1734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2017
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                    9479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                    1734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2019
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                    9479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                  1575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                    1734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2021
# Out:
#                                       name                    2005  \
# 0              Число больничных учреждений                   9 479
# 1                 из них негосударственные                     293
# 2       из них частной формы собственности                       …
# 3     Число коек в больничных учреждениях:                     NaN
# 4                              всего, тыс.                 1 575,4
# 5   из них в негосударственных учреждениях                    32,4
# 6       из них частной формы собственности                       …
# 7              на 10 000 человек населения                   110,9
# 8       Число центральных районных больниц                   1 734
# 9                         в них коек, тыс.                   345,1
# 10   средняя мощность одной больницы, коек                     199
# 11                  Число районных больниц                     267
# 12                        в них коек, тыс.                    30,8
# ...

# %%
hospital_facilities_2023
# Out:
# 0                                     name                    2010      2015  \
# 0              Число больничных учреждений                   6 308     5 433
# 1                 из них негосударственные                     224       245
# 2       из них частной формы собственности                     115       180
# 3     Число коек в больничных учреждениях:                     NaN       NaN
# 4                              всего, тыс.                1 339,51  1 222,01
# 5   из них в негосударственных учреждениях                    21,7      24,1
# 6       из них частной формы собственности                     4,1      12,8
# 7              на 10 000 человек населения                    93,8      83,4
# 8       Число центральных районных больниц                   1 754     1 426
# 9                         в них коек, тыс.                   327,1     205,6
# 10   средняя мощность одной больницы, коек                     186       144
# ...

# %% [markdown]
# ### Соединение в общий датасет

# %% [markdown]
# Так как число строк меньше только в данных из папки за 2005 год, остальные все данные по годам имеют одинаковое кол-во заполненных строк, то начнём конкатенацию с данных из папки 2007. Данные из папки 2005 присоединим в самом конце.

# %%
hospital_facilities_1 = pd.concat([hospital_facilities_2007, hospital_facilities_2009], axis=1)

hospital_facilities_1
# Out:
# 0                                      name                    1990  \
# 0               Число больничных учреждений                   12762
# 1                  из них негосударственные                     ...
# 2        из них частной формы собственности                     ...
# 3      Число коек в больничных учреждениях:                     NaN
# 4                               всего, тыс.                  2037.6
# 5   из них в негосударственных  учреждениях                     ...
# 6        из них частной формы собственности                     ...
# 7               на 10 000 человек населения                   137.4
# 8        Число центральных районных больниц                    1798
# 9                          в них коек, тыс.                   451.0
# 10   средняя мощность одной  больницы, коек                     251
# 11                   Число районных больниц                     324
# 12                         в них коек, тыс.                    33.8
# ...

# %%
hospital_facilities_2 = pd.concat([hospital_facilities_1, hospital_facilities_2011], axis=1)

hospital_facilities_2.head()
# Out:
# 0                                  name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
# 0    2006                                  name    1995    2000    2005  \
# 0    7478           Число больничных учреждений   12064   10704    9479
# 1     320              из них негосударственные      29      87     293
# 2     148   из них частной формы  собственности     ...     ...     ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4
#
# 0    2007     2008                                  name    1995    2000  \
# ...

# %%
hospital_facilities_3 = pd.concat([hospital_facilities_2, hospital_facilities_2013], axis=1)

hospital_facilities_3.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %%
hospital_facilities_4 = pd.concat([hospital_facilities_3, hospital_facilities_2015], axis=1)

hospital_facilities_4.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %%
hospital_facilities_5 = pd.concat([hospital_facilities_4, hospital_facilities_2017], axis=1)

hospital_facilities_5.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %%
hospital_facilities_6 = pd.concat([hospital_facilities_5, hospital_facilities_2019], axis=1)

hospital_facilities_6.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %%
hospital_facilities_7 = pd.concat([hospital_facilities_6, hospital_facilities_2021], axis=1)

hospital_facilities_7.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %%
hospital_facilities_8 = pd.concat([hospital_facilities_7, hospital_facilities_2023], axis=1)

hospital_facilities_8.head()
# Out:
#                                    name    1990    1995    2000    2005  \
# 0           Число больничных учреждений   12762   12064   10704    9479
# 1              из них негосударственные     ...      29      87     293
# 2    из них частной формы собственности     ...     ...     ...     ...
# 3  Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 4                           всего, тыс.  2037.6  1850.5  1671.6  1575.4
#
#      2006                                  name    1995    2000    2005  ...  \
# 0    7478           Число больничных учреждений   12064   10704    9479  ...
# 1     320              из них негосударственные      29      87     293  ...
# 2     148   из них частной формы  собственности     ...     ...     ...  ...
# 3     NaN  Число коек в больничных учреждениях:     NaN     NaN     NaN  ...
# 4  1553.6                           всего, тыс.  1850.5  1671.6  1575.4  ...
#
# ...

# %% [markdown]
# Теперь удалим столбцы дубликаты по названию

# %%
hospital_facilities_8 = hospital_facilities_8.loc[:, ~hospital_facilities_8.columns.duplicated()].copy()

# %%
hospital_facilities_8
# Out:
#                                        name                    1990  \
# 0               Число больничных учреждений                   12762
# 1                  из них негосударственные                     ...
# 2        из них частной формы собственности                     ...
# 3      Число коек в больничных учреждениях:                     NaN
# 4                               всего, тыс.                  2037.6
# 5   из них в негосударственных  учреждениях                     ...
# 6        из них частной формы собственности                     ...
# 7               на 10 000 человек населения                   137.4
# 8        Число центральных районных больниц                    1798
# 9                          в них коек, тыс.                   451.0
# 10   средняя мощность одной  больницы, коек                     251
# 11                   Число районных больниц                     324
# 12                         в них коек, тыс.                    33.8
# ...

# %% [markdown]
# Теперь присоединим ко всем данным, данные из папки за 2005 год

# %%
hospital_facilities_total = hospital_facilities_8.merge(hospital_facilities_2005, how='left')

hospital_facilities_total
# Out:
#                                        name                    1990  \
# 0               Число больничных учреждений                   12762
# 1                  из них негосударственные                     ...
# 2                  из них негосударственные                     ...
# 3        из них частной формы собственности                     ...
# 4      Число коек в больничных учреждениях:                     NaN
# 5      Число коек в больничных учреждениях:                     NaN
# 6      Число коек в больничных учреждениях:                     NaN
# 7                               всего, тыс.                  2037.6
# 8   из них в негосударственных  учреждениях                     ...
# 9        из них частной формы собственности                     ...
# 10              на 10 000 человек населения                   137.4
# 11       Число центральных районных больниц                    1798
# 12                         в них коек, тыс.                   451.0
# ...

# %% [markdown]
# После соединения уберёмя явные полные дубликаты

# %%
hospital_facilities_total = hospital_facilities_total.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# Теперь заменим запятые между цифрами на точку для корректного отображения "плавающей" точки в программе по визуализации и построению дашборов.

# %%
hospital_facilities_total = hospital_facilities_total.apply(lambda x: x.str.replace(',', '.'))

# %%
hospital_facilities_total
# Out:
#                                        name                    1990  \
# 0               Число больничных учреждений                   12762
# 1                  из них негосударственные                     ...
# 2                  из них негосударственные                     ...
# 3        из них частной формы собственности                     ...
# 4      Число коек в больничных учреждениях:                     NaN
# 5                               всего. тыс.                  2037.6
# 6   из них в негосударственных  учреждениях                     ...
# 7        из них частной формы собственности                     ...
# 8               на 10 000 человек населения                   137.4
# 9        Число центральных районных больниц                    1798
# 10                         в них коек. тыс.                   451.0
# 11   средняя мощность одной  больницы. коек                     251
# 12                   Число районных больниц                     324
# ...

# %% [markdown]
# Для корректного отображения данных с "плавающей" точкой удалим неразрывный пробел во всех строках датафрейма

# %%
hospital_facilities_total.iloc[:,1:] = hospital_facilities_total.iloc[:,1:].apply(lambda x: x.str.replace('\xa0', ''))

# %% [markdown]
# ### Создание датасетов

# %% [markdown]
# Создадим датафреймы где будут:
# - общие значения;
# - городские поселения;
# - сельская местность.

# %% [markdown]
# #### Датасет с общими значениями

# %%
hospital_facilities_total_copy = hospital_facilities_total.iloc[:18,:].copy()

hospital_facilities_total_copy
# Out:
#                                        name    1990    1995    2000    2005  \
# 0               Число больничных учреждений   12762   12064   10704    9479
# 1                  из них негосударственные     ...      29      87     293
# 2                  из них негосударственные     ...      29      87     293
# 3        из них частной формы собственности     ...     ...     ...     ...
# 4      Число коек в больничных учреждениях:     NaN     NaN     NaN     NaN
# 5                               всего. тыс.  2037.6  1850.5  1671.6  1575.4
# 6   из них в негосударственных  учреждениях     ...     2.5     7.7    32.4
# 7        из них частной формы собственности     ...     ...     ...     ...
# 8               на 10 000 человек населения   137.4   125.8   115.0   111.3
# 9        Число центральных районных больниц    1798    1786    1765    1734
# 10                         в них коек. тыс.   451.0   409.7   373.6   345.1
# ...

# %% [markdown]
# #### Датасет городских поселений

# %%
hospital_facilities_urban_settlements = hospital_facilities_total.iloc[19:30,:].copy()

hospital_facilities_urban_settlements
# Out:
#                                        name  1990    1995    2000    2005  \
# 19              Число больничных учреждений   ...    6627    6326    5820
# 20                 из них негосударственные   ...      29      87     286
# 21                 из них негосударственные   ...      29      87     286
# 22      из них частной формы  собственности   ...     ...     ...     ...
# 23                              всего. тыс.   ...  1569.2  1438.7  1365.9
# 24  из них в негосударственных  учреждениях   ...       -     7.7    32.1
# 25      из них частной формы  собственности   ...     ...     ...     ...
# 26              на 10 000 человек населения   ...   145.5   134.8   131.7
# 27       Число центральных районных больниц  1196    1103    1078    1046
# 28                   Число районных больниц   146     143     145     148
# 29                 Число участковых больниц     -      11      30      40
#
#       2006    2007     2008    2009    2010  ...     2017     2018     2019  \
# ...

# %% [markdown]
# #### Датасет сельской местности

# %%
hospital_facilities_rural_area = hospital_facilities_total.iloc[31:,:].copy()

hospital_facilities_rural_area
# Out:
#                                        name  1990   1995   2000   2005   2006  \
# 31              Число больничных учреждений   ...   5437   4378   3659   1966
# 32                 из них негосударственные   ...      -      -      7      7
# 33      из них частной формы  собственности   ...    ...    ...    ...      4
# 34                              всего. тыс.   ...  281.3  232.9  209.5  204.1
# 35  из них в негосударственных  учреждениях   ...      -      -    0.3    0.5
# 36       из них частной формы собственности   ...    ...    ...    ...    0.2
# 37              на 10 000 человек населения   ...   71.7   60.4   55.3   53.1
# 38       Число центральных районных больниц   602    683    687    688    759
# 39                   Число районных больниц   178    151    118    119     91
# 40                 Число участковых больниц  4813   4398   3280   2591    596
#
#      2007    2008   2009   2010  ...    2017    2018    2019    2020    2021  \
# ...

# %% [markdown]
# ### Транспонирование ранее созданных 3-х датасетов

# %% [markdown]
# Далее транспорнируем все три датасета, чтобы индексами были года, а колонками наименования.

# %% [markdown]
# #### Транспонированный датасет с общими значениями

# %%
hospital_facilities_total_copy = hospital_facilities_total_copy.T

hospital_facilities_total_copy
# Out:
#                                0                         1   \
# name  Число больничных учреждений  из них негосударственные
# 1990                        12762                       ...
# 1995                        12064                        29
# 2000                        10704                        87
# 2005                         9479                       293
# 2006                         7478                       320
# 2007                         6777                       333
# 2008                         6545                       253
# 2009                         6454                       224
# 2010                         6308                       224
# 2011                         6343                       220
# 2012                         6172                       225
# 2013                         5870                       233
# 2014                         5638                       246
# 2015                         5433                       245
# ...

# %% [markdown]
# Теперь сделаем первую строку названиями колонок

# %%
hospital_facilities_total_copy.columns = list(hospital_facilities_total_copy.iloc[0])

hospital_facilities_total_copy = hospital_facilities_total_copy.drop(index = 'name')

hospital_facilities_total_copy
# Out:
#      Число больничных учреждений из них негосударственные  \
# 1990                       12762                      ...
# 1995                       12064                       29
# 2000                       10704                       87
# 2005                        9479                      293
# 2006                        7478                      320
# 2007                        6777                      333
# 2008                        6545                      253
# 2009                        6454                      224
# 2010                        6308                      224
# 2011                        6343                      220
# 2012                        6172                      225
# 2013                        5870                      233
# 2014                        5638                      246
# 2015                        5433                      245
# 2016                        5357                      266
# ...

# %% [markdown]
# #### Транспонированный датасет с городскими поселениями

# %%
hospital_facilities_urban_settlements = hospital_facilities_urban_settlements.T

# изменение первой строки в названия столбцов

hospital_facilities_urban_settlements.columns = list(hospital_facilities_urban_settlements.iloc[0])

hospital_facilities_urban_settlements = hospital_facilities_urban_settlements.drop(index = 'name')

hospital_facilities_urban_settlements
# Out:
#      Число больничных учреждений из них негосударственные  \
# 1990                         ...                      ...
# 1995                        6627                       29
# 2000                        6326                       87
# 2005                        5820                      286
# 2006                        5512                      313
# 2007                        5315                      326
# 2008                        5131                      246
# 2009                        5079                      220
# 2010                        4959                      216
# 2011                        5048                      215
# 2012                        4956                      220
# 2013                        4775                      227
# 2014                        4574                      239
# 2015                        4397                      239
# 2016                        4351                      263
# ...

# %% [markdown]
# #### Транспонированный датасет сельской местности

# %%
hospital_facilities_rural_area = hospital_facilities_rural_area.T

# изменение первой строки в название столбцов

hospital_facilities_rural_area.columns = list(hospital_facilities_rural_area.iloc[0])

hospital_facilities_rural_area = hospital_facilities_rural_area.drop(index = 'name')

# %%
hospital_facilities_rural_area
# Out:
#      Число больничных учреждений из них негосударственные  \
# 1990                         ...                      ...
# 1995                        5437                        -
# 2000                        4378                        -
# 2005                        3659                        7
# 2006                        1966                        7
# 2007                        1462                        7
# 2008                        1414                        7
# 2009                        1375                        4
# 2010                        1349                        8
# 2011                        1295                        5
# 2012                        1216                        5
# 2013                        1095                        6
# 2014                        1064                        7
# 2015                        1036                        6
# 2016                        1006                        3
# ...

# %% [markdown]
# ### Сохранение датасетов в csv файл для дальнейшей визуализации

# %%
hospital_facilities_total_copy.to_csv('hospital_facilities_total_copy.csv')

# %%
hospital_facilities_urban_settlements.to_csv('hospital_facilities_urban_settlements.csv')

# %%
hospital_facilities_rural_area.to_csv('hospital_facilities_rural_area.csv')

# %% [markdown]
# ### Ссылка на дашборд

# %% [markdown]
# Дашборд выполнен в программе Tableau и доступен по [ссылке](https://public.tableau.com/views/hospital_facilities_corrected/sheet16?:language=en-US&:sid=&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# В период с 1990 по 2022 гг:
#
# - число государственных больничных организаций снизилось на 40,5%;
# - в 2.76 раза увеличилось число частных больниц;
# - количество участковых (сельских) больниц уменьшилось в 229 раза.

# %% [markdown]
# ## Дома ребенка. Ресурсы и деятельность организаций здравоохранения.

# %% [markdown]
# ### Предположение

# %% [markdown]
# За период 1990 - 2022 количество детей в домах ребенка снизилось в 3 раза.

# %% [markdown]
# ### Загрузка и предобработка файлов

# %%
сhildren_homes_2005 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2005/Ресурсы и деятельность учреждений здравоохранения/дома ребенка.csv')

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2005.columns = ['name', '1990', '1995', '2000', '2001', '2002', '2003', '2004']

сhildren_homes_2005 = сhildren_homes_2005.drop(index = 0).reset_index(drop=True)

# %%
сhildren_homes_2005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    18 non-null     object
#  1   1990    14 non-null     float64
#  2   1995    14 non-null     float64
#  3   2000    14 non-null     float64
#  4   2001    14 non-null     float64
#  5   2002    14 non-null     float64
#  6   2003    14 non-null     float64
#  7   2004    14 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 1.3+ KB

# %%
сhildren_homes_2005
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                            поступившие от родителей   5777.0   4475.0
# 10        сироты и оставшиеся без попечения родителей   5210.0   6773.0
# 11                        Выбыло детей в течение года  10741.0  10349.0
# ...

# %%
сhildren_homes_2007 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2007/Ресурсы и деятельность учреждений здравоохранения/дома ребенка.csv')

сhildren_homes_2007
# Out:
#                                                     0        1        2  \
# 0                                                 NaN   1990.0   1995.0
# 1                 Число домов ребенка (на конец года)    265.0    252.0
# 2                                В них детей, человек  18506.0  18346.0
# 3                             в том числе в возрасте:      NaN      NaN
# 4                                        0-12 месяцев   3229.0   3822.0
# 5                                            1-3 года   9283.0   8750.0
# 6                                     3 года и старше   5994.0   5774.0
# 7   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 8                      Поступило детей в течение года  10987.0  11533.0
# 9                                        в том числе:      NaN      NaN
# 10                           поступившие от родителей   5777.0   4475.0
# 11       сироты и оставшиеся без  попечения родителей   5210.0   6773.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2007.columns = ['name', '1990', '1995', '2000', '2005', '2006']

сhildren_homes_2007 = сhildren_homes_2007.drop(index = 0).reset_index(drop=True)

# %%
сhildren_homes_2007.head()
# Out:
#                                   name     1990     1995     2000     2005  \
# 0  Число домов ребенка (на конец года)    265.0    252.0    254.0    254.0
# 1                 В них детей, человек  18506.0  18346.0  19345.0  20621.0
# 2              в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                         0-12 месяцев   3229.0   3822.0   5178.0   6212.0
# 4                             1-3 года   9283.0   8750.0  10505.0  10736.0
#
#       2006
# 0    249.0
# 1  20342.0
# 2      NaN
# 3   5598.0
# 4  11181.0

# %%
сhildren_homes_2009 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2009/Ресурсы и деятельность учреждений здравоохранения/дома ребенка.csv')

сhildren_homes_2009
# Out:
#                                                     0        1        2  \
# 0                                                 NaN   1995.0   2000.0
# 1                 Число домов ребенка (на конец года)    252.0    254.0
# 2                                В них детей, человек  18346.0  19345.0
# 3                             в том числе в возрасте:      NaN      NaN
# 4                                        0-12 месяцев   3822.0   5178.0
# 5                                            1-3 года   8750.0  10505.0
# 6                                     3 года и старше   5774.0   3662.0
# 7   Из общей численности детей - сироты и оставшие...  10455.0  14115.0
# 8                      Поступило детей в течение года  11533.0  13291.0
# 9                                        в том числе:      NaN      NaN
# 10                           поступившие от родителей   4475.0   3471.0
# 11        сироты и оставшиеся без попечения родителей   6773.0   9820.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2009.columns = ['name', '1995', '2000', '2005', '2007', '2008']

сhildren_homes_2009 = сhildren_homes_2009.drop(index = 0).reset_index(drop=True)

# %%
сhildren_homes_2009.head()
# Out:
#                                   name     1995     2000     2005     2007  \
# 0  Число домов ребенка (на конец года)    252.0    254.0    254.0    249.0
# 1                 В них детей, человек  18346.0  19345.0  20621.0  18480.0
# 2              в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                         0-12 месяцев   3822.0   5178.0   6212.0   4768.0
# 4                             1-3 года   8750.0  10505.0  10736.0   9856.0
#
#       2008
# 0    244.0
# 1  17781.0
# 2      NaN
# 3   5052.0
# 4   8988.0

# %%
сhildren_homes_2011 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2011/Ресурсы и деятельность учреждений здравоохранения/дома ребенка.csv')

сhildren_homes_2011
# Out:
#                                                     0        1        2  \
# 0                                                 NaN   1995.0   2000.0
# 1                 Число домов ребенка (на конец года)    252.0    254.0
# 2                                В них детей, человек  18346.0  19345.0
# 3                             в том числе в возрасте:      NaN      NaN
# 4                                        0-12 месяцев   3822.0   5178.0
# 5                                            1-3 года   8750.0  10505.0
# 6                                     3 года и старше   5774.0   3662.0
# 7   Из общей численности детей - сироты и оставшие...  10455.0  14115.0
# 8                      Поступило детей в течение года  11533.0  13291.0
# 9                                        в том числе:      NaN      NaN
# 10                           поступившие от родителей   4475.0   3471.0
# 11        сироты и оставшиеся без попечения родителей   6773.0   9820.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2011.columns = ['name', '1995', '2000', '2005', '2009', '2010']

сhildren_homes_2011 = сhildren_homes_2011.drop(index = 0).reset_index(drop=True)

# %%
сhildren_homes_2011
# Out:
#                                                  name     1995     2000  \
# 0                 Число домов ребенка (на конец года)    252.0    254.0
# 1                                В них детей, человек  18346.0  19345.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3822.0   5178.0
# 4                                            1-3 года   8750.0  10505.0
# 5                                     3 года и старше   5774.0   3662.0
# 6   Из общей численности детей - сироты и оставшие...  10455.0  14115.0
# 7                      Поступило детей в течение года  11533.0  13291.0
# 8                                        в том числе:      NaN      NaN
# 9                            поступившие от родителей   4475.0   3471.0
# 10        сироты и оставшиеся без попечения родителей   6773.0   9820.0
# 11                        Выбыло детей в течение года  10349.0  12895.0
# ...

# %%
сhildren_homes_2013 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2013/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.4. дома ребенка1).csv')

сhildren_homes_2013
# Out:
#                                            Unnamed: 0     2000     2005  \
# 0                 Число домов ребенка (на конец года)    254.0    254.0
# 1                                В них детей, человек  19345.0  20621.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   5178.0   6212.0
# 4                                            1-3 года  10505.0  10736.0
# 5                                     3 года и старше   3662.0   3673.0
# 6   Из общей численности детей – сироты и оставшие...  14115.0  16317.0
# 7                      Поступило детей в течение года  13291.0  15068.0
# 8                                        в том числе:      NaN      NaN
# 9                           поступившие от родителей    3471.0   3037.0
# 10        сироты и оставшиеся без попечения родителей   9820.0  12031.0
# 11                        Выбыло детей в течение года  12895.0  13949.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2013.columns = ['name', '2000', '2005', '2010', '2011', '2012']

сhildren_homes_2013
# Out:
#                                                  name     2000     2005  \
# 0                 Число домов ребенка (на конец года)    254.0    254.0
# 1                                В них детей, человек  19345.0  20621.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   5178.0   6212.0
# 4                                            1-3 года  10505.0  10736.0
# 5                                     3 года и старше   3662.0   3673.0
# 6   Из общей численности детей – сироты и оставшие...  14115.0  16317.0
# 7                      Поступило детей в течение года  13291.0  15068.0
# 8                                        в том числе:      NaN      NaN
# 9                           поступившие от родителей    3471.0   3037.0
# 10        сироты и оставшиеся без попечения родителей   9820.0  12031.0
# 11                        Выбыло детей в течение года  12895.0  13949.0
# ...

# %%
сhildren_homes_2015 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2015/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.4. дома ребенка1).csv')

сhildren_homes_2015
# Out:
#                                            Unnamed: 0     2005     2010  \
# 0                 Число домов ребенка (на конец года)    254.0    227.0
# 1                                В них детей, человек  20621.0  17483.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   6212.0   4493.0
# 4                                            1-3 года  10736.0   9676.0
# 5                                     3 года и старше   3673.0   3314.0
# 6   Из общей численности детей – сироты и оставшие...  16317.0  12707.0
# 7                      Поступило детей в течение года  15068.0  15010.0
# 8                                        в том числе:      NaN      NaN
# 9                           поступившие от родителей    3037.0   4907.0
# 10        сироты и оставшиеся без попечения родителей  12031.0  10071.0
# 11                        Выбыло детей в течение года  13949.0  14988.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2015.columns = ['name', '2005', '2010', '2011', '2012', '2013', '2014']

сhildren_homes_2015.head()
# Out:
#                                   name     2005     2010     2011     2012  \
# 0  Число домов ребенка (на конец года)    254.0    227.0    218.0    207.0
# 1                 В них детей, человек  20621.0  17483.0  16296.0  15993.0
# 2              в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                         0-12 месяцев   6212.0   4493.0   3998.0   3977.0
# 4                             1-3 года  10736.0   9676.0   8884.0   8427.0
#
#       2013     2014
# 0    194.0    176.0
# 1  13977.0  11530.0
# 2      NaN      NaN
# 3   3358.0   2821.0
# 4   7219.0   6024.0

# %%
сhildren_homes_2017 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2017/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.4. дома ребенка1).csv')

сhildren_homes_2017
# Out:
#                                            Unnamed: 0     2005     2010  \
# 0                 Число домов ребенка (на конец года)    254.0    227.0
# 1                                В них детей, человек  20621.0  17483.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   6212.0   4493.0
# 4                                            1-3 года  10736.0   9676.0
# 5                                     3 года и старше   3673.0   3314.0
# 6   Из общей численности детей – сироты и оставшие...  16317.0  12707.0
# 7                      Поступило детей в течение года  15068.0  15010.0
# 8                                        в том числе:      NaN      NaN
# 9                           поступившие от родителей    3037.0   4907.0
# 10        сироты и оставшиеся без попечения родителей  12031.0  10071.0
# 11                        Выбыло детей в течение года  13949.0  14988.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2017.columns = ['name', '2005', '2010', '2013', '2014', '2015', '2016']

сhildren_homes_2017.head()
# Out:
#                                   name     2005     2010     2013     2014  \
# 0  Число домов ребенка (на конец года)    254.0    227.0    194.0    176.0
# 1                 В них детей, человек  20621.0  17483.0  13977.0  11530.0
# 2              в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                         0-12 месяцев   6212.0   4493.0   3358.0   2821.0
# 4                             1-3 года  10736.0   9676.0   7219.0   6024.0
#
#       2015    2016
# 0    166.0   161.0
# 1  10245.0  8575.0
# 2      NaN     NaN
# 3   2373.0  2133.0
# 4   5456.0  4549.0

# %%
сhildren_homes_2019 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2019/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.4. дома ребенка1).csv')

сhildren_homes_2019
# Out:
#                                            Unnamed: 0     2005     2010  \
# 0               Число домов ребенка \n(на конец года)    254.0    227.0
# 1                                В них детей, человек  20621.0  17483.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                      0 – 12 месяцев   6212.0   4493.0
# 4                                          1 – 3 года  10736.0   9676.0
# 5                                     3 года и старше   3673.0   3314.0
# 6   Из общей численности детей – сироты и оставшие...  16317.0  12707.0
# 7                      Поступило детей в течение года  15068.0  15010.0
# 8                                        в том числе:      NaN      NaN
# 9                           поступившие от родителей    3037.0   4907.0
# 10        сироты и оставшиеся без попечения родителей  12031.0  10071.0
# 11                        Выбыло детей в течение года  13949.0  14988.0
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2019.columns = ['name', '2005', '2010', '2015', '2016', '2017', '2018']

сhildren_homes_2019.head()
# Out:
#                                     name     2005     2010     2015    2016  \
# 0  Число домов ребенка \n(на конец года)    254.0    227.0    166.0   161.0
# 1                   В них детей, человек  20621.0  17483.0  10245.0  8575.0
# 2                в том числе в возрасте:      NaN      NaN      NaN     NaN
# 3                         0 – 12 месяцев   6212.0   4493.0   2373.0  2133.0
# 4                             1 – 3 года  10736.0   9676.0   5456.0  4549.0
#
#      2017    2018
# 0   154.0   145.0
# 1  7774.0  7524.0
# 2     NaN     NaN
# 3  1989.0  1968.0
# 4  4077.0  3920.0

# %%
сhildren_homes_2021 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2021/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.4. дома ребенка1).csv')

сhildren_homes_2021
# Out:
#                                            Unnamed: 0    2005    2010    2015  \
# 0               Число домов ребенка \n(на конец года)     254     227     166
# 1                                В них детей, человек  20 621  17 483  10 245
# 2                             в том числе в возрасте:     NaN     NaN     NaN
# 3                                      0 – 12 месяцев   6 212   4 493   2 373
# 4                                          1 – 3 года  10 736   9 676   5 456
# 5                                     3 года и старше   3 673   3 314   2 416
# 6   Из общей численности детей – сироты и оставшие...  16 317  12 707   5 439
# 7                      Поступило детей в течение года  15 068  15 010  11 984
# 8                                        в том числе:     NaN     NaN     NaN
# 9                           поступившие от родителей    3 037   4 907   5 800
# 10        сироты и оставшиеся без попечения родителей  12 031  10 071   6 142
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2021.columns = ['name', '2005', '2010', '2015', '2018', '2019', '2020']

сhildren_homes_2021.head()
# Out:
#                                     name    2005    2010    2015   2018  \
# 0  Число домов ребенка \n(на конец года)     254     227     166    145
# 1                   В них детей, человек  20 621  17 483  10 245  7 524
# 2                в том числе в возрасте:     NaN     NaN     NaN    NaN
# 3                         0 – 12 месяцев   6 212   4 493   2 373  1 968
# 4                             1 – 3 года  10 736   9 676   5 456  3 920
#
#     2019   2020
# 0    139    136
# 1  7 059  6 166
# 2    NaN    NaN
# 3  1 764  1 480
# 4  3 747  3 244

# %%
сhildren_homes_2023 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2023/3.4. ДОМА РЕБЕНКА1) - 3.4.csv')

сhildren_homes_2023
# Out:
#                                   3.4. ДОМА РЕБЕНКА1) Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN       2010       2015
# 1                 Число домов ребенка (на конец года)        227        166
# 2                                В них детей, человек     17 483     10 245
# 3                             в том числе в возрасте:        NaN        NaN
# 4                                      0 – 12 месяцев      4 493      2 373
# 5                                          1 – 3 года      9 676      5 456
# 6                                     3 года и старше      3 314      2 416
# 7   Из общей численности детей – сироты и оставшие...     12 707      5 439
# 8                      Поступило детей в течение года     15 010     11 984
# 9                                        в том числе:        NaN        NaN
# 10                          поступившие от родителей       4 907      5 800
# ...

# %% [markdown]
# Сделаем понятными названия столбцов - по годам

# %%
сhildren_homes_2023.columns = ['name', '2010', '2015', '2019', '2020', '2021', '2022']

сhildren_homes_2023 = сhildren_homes_2023.drop(index = 0).reset_index(drop=True)

# %%
сhildren_homes_2023.head()
# Out:
#                                   name    2010    2015   2019   2020   2021  \
# 0  Число домов ребенка (на конец года)     227     166    139    136    134
# 1                 В них детей, человек  17 483  10 245  7 059  6 166  5 968
# 2              в том числе в возрасте:     NaN     NaN    NaN    NaN    NaN
# 3                       0 – 12 месяцев   4 493   2 373  1 764  1 480  1 444
# 4                           1 – 3 года   9 676   5 456  3 747  3 244  3 069
#
#     2022
# 0    116
# 1  5 324
# 2    NaN
# 3  1 282
# 4  2 770

# %% [markdown]
# Для унификации названий в колонке name, возьмем за основу названия 2005 года, сохраним их в отдельную переменную и запишем по остальным годам эти названия в колонку name

# %%
name_unified = сhildren_homes_2005['name']

# %%
сhildren_homes_2007['name'] = name_unified

# %%
сhildren_homes_2009['name'] = name_unified

# %%
сhildren_homes_2011['name'] = name_unified

# %%
сhildren_homes_2013['name'] = name_unified

# %%
сhildren_homes_2015['name'] = name_unified

# %%
сhildren_homes_2017['name'] = name_unified

# %%
сhildren_homes_2019['name'] = name_unified

# %%
сhildren_homes_2021['name'] = name_unified

# %%
сhildren_homes_2023['name'] = name_unified

# %% [markdown]
# ### Соединяем данные из всех папок в один датафрейм

# %%
сhildren_homes_1 = сhildren_homes_2005.merge(сhildren_homes_2007, how='left')

сhildren_homes_1
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                                        в том числе:      NaN      NaN
# 10                           поступившие от родителей   5777.0   4475.0
# 11        сироты и оставшиеся без попечения родителей   5210.0   6773.0
# ...

# %%
сhildren_homes_2 = сhildren_homes_1.merge(сhildren_homes_2009, how='left')

сhildren_homes_2
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                                        в том числе:      NaN      NaN
# 10                                       в том числе:      NaN      NaN
# 11                                       в том числе:      NaN      NaN
# ...

# %%
сhildren_homes_3 = сhildren_homes_2.merge(сhildren_homes_2011, how='left')

сhildren_homes_3
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                                        в том числе:      NaN      NaN
# 10                                       в том числе:      NaN      NaN
# 11                                       в том числе:      NaN      NaN
# ...

# %%
сhildren_homes_4 = сhildren_homes_3.merge(сhildren_homes_2013, how='left')

сhildren_homes_4
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                                        в том числе:      NaN      NaN
# 10                                       в том числе:      NaN      NaN
# 11                                       в том числе:      NaN      NaN
# ...

# %%
сhildren_homes_5 = сhildren_homes_4.merge(сhildren_homes_2015, how='left')

сhildren_homes_5
# Out:
#                                    name     1990     1995     2000     2001  \
# 0   Число домов ребенка (на конец года)    265.0    252.0    254.0    246.0
# 1                  В них детей, человек  18506.0  18346.0  19345.0  19356.0
# 2               в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                          0-12 месяцев   3229.0   3822.0   5178.0   5219.0
# 4                              1-3 года   9283.0   8750.0  10505.0   9999.0
# ..                                  ...      ...      ...      ...      ...
# 75                     взято родителями   3643.0   3061.0   2871.0   2591.0
# 76                взято для усыновления   2060.0   3727.0   6689.0   6665.0
# 77        Численность детей, отстающих:      NaN      NaN      NaN      NaN
# 78                в физическом развитии   8941.0  10545.0  11174.0  10807.0
# 79               в психическом развитии  12999.0  15271.0  15872.0  15874.0
#
# ...

# %%
сhildren_homes_6 = сhildren_homes_5.merge(сhildren_homes_2017, how='left')

сhildren_homes_6
# Out:
#                                     name     1990     1995     2000     2001  \
# 0    Число домов ребенка (на конец года)    265.0    252.0    254.0    246.0
# 1                   В них детей, человек  18506.0  18346.0  19345.0  19356.0
# 2                в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                           0-12 месяцев   3229.0   3822.0   5178.0   5219.0
# 4                               1-3 года   9283.0   8750.0  10505.0   9999.0
# ..                                   ...      ...      ...      ...      ...
# 139                     взято родителями   3643.0   3061.0   2871.0   2591.0
# 140                взято для усыновления   2060.0   3727.0   6689.0   6665.0
# 141        Численность детей, отстающих:      NaN      NaN      NaN      NaN
# 142                в физическом развитии   8941.0  10545.0  11174.0  10807.0
# 143               в психическом развитии  12999.0  15271.0  15872.0  15874.0
#
# ...

# %%
сhildren_homes_7 = сhildren_homes_6.merge(сhildren_homes_2019, how='left')

сhildren_homes_7
# Out:
#                                     name     1990     1995     2000     2001  \
# 0    Число домов ребенка (на конец года)    265.0    252.0    254.0    246.0
# 1                   В них детей, человек  18506.0  18346.0  19345.0  19356.0
# 2                в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                           0-12 месяцев   3229.0   3822.0   5178.0   5219.0
# 4                               1-3 года   9283.0   8750.0  10505.0   9999.0
# ..                                   ...      ...      ...      ...      ...
# 267                     взято родителями   3643.0   3061.0   2871.0   2591.0
# 268                взято для усыновления   2060.0   3727.0   6689.0   6665.0
# 269        Численность детей, отстающих:      NaN      NaN      NaN      NaN
# 270                в физическом развитии   8941.0  10545.0  11174.0  10807.0
# 271               в психическом развитии  12999.0  15271.0  15872.0  15874.0
#
# ...

# %%
сhildren_homes_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    272 non-null    object
#  1   1990    14 non-null     float64
#  2   1995    14 non-null     float64
#  3   2000    14 non-null     float64
#  4   2001    14 non-null     float64
#  5   2002    14 non-null     float64
#  6   2003    14 non-null     float64
#  7   2004    14 non-null     float64
#  8   2005    14 non-null     float64
#  9   2006    14 non-null     float64
#  10  2007    14 non-null     float64
#  11  2008    14 non-null     float64
#  12  2009    14 non-null     float64
#  13  2010    14 non-null     float64
#  14  2011    14 non-null     float64
#  15  2012    14 non-null     float64
#  16  2013    14 non-null     float64
#  17  2014    14 non-null     float64
#  18  2015    14 non-null     float64
#  19  2016    14 non-null     float64
# ...

# %% [markdown]
# Заменим неразрывный пробел в датафрейме `сhildren_homes_2021` для дальнейшего преобразования этих колонок к типу float с целью соединеия в общий датафрейм.

# %%
сhildren_homes_2021.iloc[:,1:] = сhildren_homes_2021.iloc[:,1:].apply(lambda x: x.str.replace('\xa0', ''))

# %% [markdown]
# Теперь произведём в цикле изменения всех записей в колонках по годам с типа object на тип float64

# %%
for names, values in сhildren_homes_2021.iloc[:,1:].items():
    сhildren_homes_2021[names] = values.astype('float')

# %%
сhildren_homes_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    18 non-null     object
#  1   2005    14 non-null     float64
#  2   2010    14 non-null     float64
#  3   2015    14 non-null     float64
#  4   2018    14 non-null     float64
#  5   2019    14 non-null     float64
#  6   2020    14 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.1+ KB

# %%
сhildren_homes_8 = сhildren_homes_7.merge(сhildren_homes_2021, how='left')

сhildren_homes_8
# Out:
#                                     name     1990     1995     2000     2001  \
# 0    Число домов ребенка (на конец года)    265.0    252.0    254.0    246.0
# 1                   В них детей, человек  18506.0  18346.0  19345.0  19356.0
# 2                в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                           0-12 месяцев   3229.0   3822.0   5178.0   5219.0
# 4                               1-3 года   9283.0   8750.0  10505.0   9999.0
# ..                                   ...      ...      ...      ...      ...
# 523                     взято родителями   3643.0   3061.0   2871.0   2591.0
# 524                взято для усыновления   2060.0   3727.0   6689.0   6665.0
# 525        Численность детей, отстающих:      NaN      NaN      NaN      NaN
# 526                в физическом развитии   8941.0  10545.0  11174.0  10807.0
# 527               в психическом развитии  12999.0  15271.0  15872.0  15874.0
#
# ...

# %% [markdown]
# Изменим тип данных датафрейма `сhildren_homes_2023` в колонках по годам с object на тип float64 в цикле. Но перед этим удалим неразрывный пробел.

# %%
сhildren_homes_2023.iloc[:, 1:] = сhildren_homes_2023.iloc[:, 1:].apply(lambda x: x.str.replace('\xa0', ''))

# %%
for names, values in сhildren_homes_2023.iloc[:,1:].items():
    сhildren_homes_2023[names] = values.astype('float')

# %%
сhildren_homes_total = сhildren_homes_8.merge(сhildren_homes_2023, how='left')

сhildren_homes_total
# Out:
#                                      name     1990     1995     2000     2001  \
# 0     Число домов ребенка (на конец года)    265.0    252.0    254.0    246.0
# 1                    В них детей, человек  18506.0  18346.0  19345.0  19356.0
# 2                 в том числе в возрасте:      NaN      NaN      NaN      NaN
# 3                            0-12 месяцев   3229.0   3822.0   5178.0   5219.0
# 4                                1-3 года   9283.0   8750.0  10505.0   9999.0
# ...                                   ...      ...      ...      ...      ...
# 1035                     взято родителями   3643.0   3061.0   2871.0   2591.0
# 1036                взято для усыновления   2060.0   3727.0   6689.0   6665.0
# 1037        Численность детей, отстающих:      NaN      NaN      NaN      NaN
# 1038                в физическом развитии   8941.0  10545.0  11174.0  10807.0
# 1039               в психическом развитии  12999.0  15271.0  15872.0  15874.0
#
# ...

# %% [markdown]
# Удалим образовавшиеся дубликаты

# %%
сhildren_homes_total = сhildren_homes_total.drop_duplicates().reset_index(drop=True)

сhildren_homes_total
# Out:
#                                                  name     1990     1995  \
# 0                 Число домов ребенка (на конец года)    265.0    252.0
# 1                                В них детей, человек  18506.0  18346.0
# 2                             в том числе в возрасте:      NaN      NaN
# 3                                        0-12 месяцев   3229.0   3822.0
# 4                                            1-3 года   9283.0   8750.0
# 5                                     3 года и старше   5994.0   5774.0
# 6   Из общей численности детей - сироты и оставшие...   4269.0  10455.0
# 7                      Поступило детей в течение года  10987.0  11533.0
# 8                                        в том числе:      NaN      NaN
# 9                            поступившие от родителей   5777.0   4475.0
# 10        сироты и оставшиеся без попечения родителей   5210.0   6773.0
# 11                        Выбыло детей в течение года  10741.0  10349.0
# ...

# %% [markdown]
# Перед сохранением датафрейма изменим все значения float на int. Для этого сначала все nan заменим на "0"

# %%
сhildren_homes_total = сhildren_homes_total.fillna(0)

# %%
for names, values in сhildren_homes_total.iloc[:, 1:].items():
    сhildren_homes_total[names] = values.astype('int')

# %% [markdown]
# Перед сохранением таблицы, сначала её транспонируем

# %%
сhildren_homes_total = сhildren_homes_total.set_index('name')

сhildren_homes_total = сhildren_homes_total.T

# %% [markdown]
# Также приведём все названия к нижнему регистру

# %%
сhildren_homes_total.columns = [x.lower() for x in сhildren_homes_total.columns]

# %%
сhildren_homes_total
# Out:
#       число домов ребенка (на конец года)  в них детей, человек  \
# 1990                                  265                 18506
# 1995                                  252                 18346
# 2000                                  254                 19345
# 2001                                  246                 19356
# 2002                                  249                 19337
# 2003                                  251                 19113
# 2004                                  255                 19962
# 2005                                  254                 20621
# 2006                                  249                 20342
# 2007                                  249                 18480
# 2008                                  244                 17781
# 2009                                  243                 17767
# 2010                                  227                 17483
# 2011                                  218                 16296
# ...

# %% [markdown]
# Сохраняем датасет в файл

# %%
сhildren_homes_total.to_csv('сhildren_homes_1990_2022.csv')

# %% [markdown]
# ### Ссылка на дашборд

# %% [markdown]
# Дашборд выполнен в программе Tableau и доступен по [ссылке](https://public.tableau.com/views/hildren_homes_1990_2022/Dashboard1?:language=en-US&:sid=&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# В период с 1990 по 2022 гг количество детей в домах ребенка снизилось в 3,5 раза

# %% [markdown]
# ## Коечный фонд по специализации в Субъектах Российской Федерации. Ресурсы и деятельность организаций здравоохранения.

# %% [markdown]
# ### Предположение

# %% [markdown]
# За период 2004 - 2012 в структуре коечного фонда количество онкологических и инфекционных коек выросло, а количество коек для беременных, рожениц и родильниц снизилось на 30%. Но при этом количество амбулаторных медицинских организаций (поликлиник) выросло более чем на 30%.

# %% [markdown]
# ### Загрузка данных

# %%
bed_fund_2005 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2005/Ресурсы и деятельность учреждений здравоохранения/число больничных коек по специализации по регионам российской федерации в 2004 г..csv')

bed_fund_2005
# Out:
#                                          0                  1  \
# 0                                      NaN  Терапев- тические
# 1                     Российская Федерация             340402
# 2            Центральный федеральный округ              94464
# 3                     Белгородская область               3632
# 4                         Брянская область               3252
# ..                                     ...                ...
# 95  в том числе Корякский автономный округ                214
# 96                     Магаданская область                557
# 97                     Сахалинская область               1416
# 98            Еврейская автономная область                281
# 99              Чукотский автономный округ                190
#
#                   2                 3                   4                5  \
# 0   Хирур- гические  Онколо- гические  Гинеко- логические  Туберку- лезные
# ...

# %%
bed_fund_2007 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2007/Ресурсы и деятельность учреждений здравоохранения/число больничных коек по специализации по субъектам российской федерации в 2006 г..csv')

bed_fund_2007
# Out:
#                                          0                  1  \
# 0                                      NaN  Терапев- тические
# 1                     Российская Федерация             324507
# 2            Центральный федеральный округ              88038
# 3                     Белгородская область               3268
# 4                         Брянская область               3236
# ..                                     ...                ...
# 94  в том числе Корякский автономный округ                159
# 95                     Магаданская область                455
# 96                     Сахалинская область               1481
# 97            Еврейская автономная область                264
# 98              Чукотский автономный округ                198
#
#                   2                 3                     4                5  \
# 0   Хирур- гические  Онколо- гические  Гинеко- логичес- кие  Туберку- лезные
# ...

# %%
bed_fund_2009 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2009/Ресурсы и деятельность учреждений здравоохранения/число больничных коек по специализации по субъектам российской федерации в 2008 г. начало.csv')

bed_fund_2009
# Out:
#                                 0                           1  \
# 0                             NaN  Терапев- тического профиля
# 1            Российская Федерация                      251264
# 2   Центральный федеральный округ                       69055
# 3            Белгородская область                        2486
# 4                Брянская область                        2411
# ..                            ...                         ...
# 88               Амурская область                        1827
# 89            Магаданская область                         424
# 90            Сахалинская область                        1150
# 91   Еврейская автономная область                         230
# 92     Чукотский автономный округ                         160
#
#                            2                 3                   4  \
# 0   Хирурги- ческого профиля  Онкологи- ческие  Гинеколо- гические
# 1                     264559             39018               72725
# ...

# %%
bed_fund_2011 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2011/Ресурсы и деятельность учреждений здравоохранения/число больничных коек по специализации по субъектам российской федерации в 2010 г. начало.csv')

bed_fund_2011
# Out:
#                                 0                           1  \
# 0                             NaN  Терапевтиче- ского профиля
# 1            Российская Федерация                      296103
# 2   Центральный федеральный округ                       80054
# 3            Белгородская область                        2983
# 4                Брянская область                        2725
# ..                            ...                         ...
# 89               Амурская область                        2049
# 90            Магаданская область                         420
# 91            Сахалинская область                        1401
# 92   Еврейская автономная область                         273
# 93     Чукотский автономный округ                         116
#
#                            2                 3                   4  \
# 0   Хирургиче- ского профиля  Онкологи- ческие  Гинеколо- гические
# 1                     257185             39718               68779
# ...

# %%
bed_fund_2013 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2013/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.15. число больничных коек по специализации по субъектам российской федерации в 2012 г..csv')

bed_fund_2013
# Out:
#                                  Unnamed: 0  Терапевтического\nпрофиля  \
# 0                      Российская Федерация                     302797
# 1           Центральный \nфедеральный округ                      82632
# 2                      Белгородская область                       3133
# 3                          Брянская область                       2787
# 4                      Владимирская область                       2823
# 5                       Воронежская область                       5381
# 6                        Ивановская область                       2775
# 7                         Калужская область                       2245
# 8                       Костромская область                       1277
# 9                           Курская область                       2300
# 10                         Липецкая область                       2204
# 11                       Московская область                      13440
# ...

# %%
bed_fund_2015 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2015/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.2. число больничных коек по специализации.csv')

bed_fund_2015
# Out:
#                                  Unnamed: 0                           2005  \
# 0                                       NaN               Всего, тыс. коек
# 1                     Всего больничных коек                         1575,4
# 2                                   из них:                            NaN
# 3                  терапевтического профиля                          329,7
# 4                    хирургического профиля                          279,7
# 5                            онкологических                           38,3
# 6                          гинекологических                           81,7
# 7                             туберкулезных                           84,3
# 8                              инфекционных                           84,6
# 9                        офтальмологических                           26,3
# 10                     отоларингологических                           24,5
# ...

# %%
bed_fund_2017 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2017/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.2. число больничных коек по специализации.csv')

bed_fund_2017
# Out:
#                                  Unnamed: 0                           2005  \
# 0                                       NaN               Всего, тыс. коек
# 1                     Всего больничных коек                         1575,4
# 2                                   из них:                            NaN
# 3                  терапевтического профиля                          329,7
# 4                    хирургического профиля                          279,7
# 5                            онкологических                           38,3
# 6                          гинекологических                           81,7
# 7                             туберкулезных                           84,3
# 8                              инфекционных                           84,6
# 9                        офтальмологических                           26,3
# 10                     отоларингологических                           24,5
# ...

# %%
bed_fund_2019 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2019/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.2. число больничных коек по специализации.csv')

bed_fund_2019
# Out:
#                                  Unnamed: 0                           2005  \
# 0                                       NaN               Всего, тыс. коек
# 1                     Всего больничных коек                         1575,4
# 2                                   из них:                            NaN
# 3                  терапевтического профиля                          329,7
# 4                    хирургического профиля                          279,7
# 5                            онкологических                           38,3
# 6                          гинекологических                           81,7
# 7                             туберкулезных                           84,3
# 8                              инфекционных                           84,6
# 9                        офтальмологических                           26,3
# 10                 оториноларингологических                           24,5
# ...

# %%
bed_fund_2021 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2021/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.2. число больничных коек по специализации.csv')

bed_fund_2021
# Out:
#                                  Unnamed: 0                           2005  \
# 0                                       NaN               Всего, тыс. коек
# 1                     Всего больничных коек                        1 575,4
# 2                                   из них:                            NaN
# 3                  терапевтического профиля                          329,7
# 4                    хирургического профиля                          279,7
# 5                            онкологических                           38,3
# 6                          гинекологических                           81,7
# 7                             туберкулезных                           84,3
# 8                              инфекционных                           84,6
# 9                        офтальмологических                           26,3
# 10                 оториноларингологических                           24,5
# ...

# %%
bed_fund_2023 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2023/3.2. ЧИСЛО БОЛЬНИЧНЫХ КОЕК ПО СПЕЦИАЛИЗАЦИИ - 3.2.csv')

bed_fund_2023
# Out:
#           3.2. ЧИСЛО БОЛЬНИЧНЫХ КОЕК ПО СПЕЦИАЛИЗАЦИИ  \
# 0                                                 NaN
# 1                                                 NaN
# 2                               Всего больничных коек
# 3                                             из них:
# 4                            терапевтического профиля
# 5                              хирургического профиля
# 6                                      онкологических
# 7                                    гинекологических
# 8                                       туберкулезных
# 9                                        инфекционных
# 10                                 офтальмологических
# 11                           оториноларингологических
# 12                           дермато-венерологических
# 13                                   психиатрических
# 14                                    наркологических
# 15                                    неврологических
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Данные из папки за 2005 год

# %% [markdown]
# Возьмем первую строку датафрейма и сделаем название колонок ею и потом сразу удалим её

# %%
bed_fund_2005.columns = list(bed_fund_2005.iloc[0])

# %%
bed_fund_2005 = bed_fund_2005.drop(index = 0)

# %% [markdown]
# Теперь удалим все тире в названиях колонок

# %%
bed_fund_2005.columns = bed_fund_2005.columns.fillna('субъект')

# %%
bed_fund_2005.columns = [x.replace('-', '') for x in bed_fund_2005.columns]

# %% [markdown]
# Также удалим все пробелы между словами, сохраним их в отдельную переменную и передадим ей новый список названий колонок и запишем эти новые названия колонок в датафрейм

# %%
column = list(bed_fund_2005.columns)

new_column = [i.replace(' ', '') for i in column]

bed_fund_2005.columns = new_column

# %% [markdown]
# Добавим самым первым столбцов год, из которого мы берём данные для дальнейшей визуализации в динамике

# %%
bed_fund_2005.insert(0, 'год', '2004')

# %%
bed_fund_2005.head()
# Out:
#     год                        субъект Терапевтические Хирургические  \
# 1  2004           Российская Федерация          340402        284959
# 2  2004  Центральный федеральный округ           94464         79474
# 3  2004           Белгородская область            3632          3060
# 4  2004               Брянская область            3252          2861
# 5  2004           Владимирская область            3624          2792
#
#   Онкологические Гинекологические Туберкулезные Инфекционные  \
# 1          38092            82306         84578        87995
# 2          11166            21166         18325        21506
# 3            365              828           705          960
# 4            335              871           820          907
# 5            365              829           711          906
#
#   Офтальмологические Отоларингологические Дерматовенерологические  \
# 1              26568                25171                   22421
# ...

# %% [markdown]
# #### Данные из папки 2007 года

# %%
bed_fund_2007.head()
# Out:
#                                0                  1                2  \
# 0                            NaN  Терапев- тические  Хирур- гические
# 1           Российская Федерация             324507           277026
# 2  Центральный федеральный округ              88038            76979
# 3           Белгородская область               3268             2809
# 4               Брянская область               3236             2808
#
#                   3                     4                5               6  \
# 0  Онколо- гические  Гинеко- логичес- кие  Туберку- лезные  Инфек- ционные
# 1             38813                 79123            84067           81370
# 2             11231                 20490            18010           19535
# 3               360                   761              645             868
# 4               335                   890              820             843
#
#                         7                         8  \
# ...

# %% [markdown]
# Для датафрейма `bed_fund_2007` проведем аналогичные операции по данным из папки за 2005 год

# %%
bed_fund_2007.columns = list(bed_fund_2007.iloc[0])

# %%
bed_fund_2007 = bed_fund_2007.drop(index = 0)

# %%
bed_fund_2007.columns = bed_fund_2007.columns.fillna('субъект')

# %%
bed_fund_2007.columns = [x.replace('-', '') for x in bed_fund_2007.columns]

# %%
column = list(bed_fund_2007.columns)

new_column = [i.replace(' ', '') for i in column]

bed_fund_2007.columns = new_column

# %%
bed_fund_2007.insert(0, 'год', '2006')

bed_fund_2007.head()
# Out:
#     год                        субъект Терапевтические Хирургические  \
# 1  2006           Российская Федерация          324507        277026
# 2  2006  Центральный федеральный округ           88038         76979
# 3  2006           Белгородская область            3268          2809
# 4  2006               Брянская область            3236          2808
# 5  2006           Владимирская область            3138          2574
#
#   Онкологические Гинекологические Туберкулезные Инфекционные  \
# 1          38813            79123         84067        81370
# 2          11231            20490         18010        19535
# 3            360              761           645          868
# 4            335              890           820          843
# 5            354              623           621          695
#
#   Офтальмологические Отоларингологические Дерматовенерологические  \
# 1              26029                23665                   20426
# ...

# %% [markdown]
# #### Данные из папки 2009 года

# %%
bed_fund_2009.head()
# Out:
#                                0                           1  \
# 0                            NaN  Терапев- тического профиля
# 1           Российская Федерация                      251264
# 2  Центральный федеральный округ                       69055
# 3           Белгородская область                        2486
# 4               Брянская область                        2411
#
#                           2                 3                   4  \
# 0  Хирурги- ческого профиля  Онкологи- ческие  Гинеколо- гические
# 1                    264559             39018               72725
# 2                     73783             11051               18724
# 3                      2497               365                 642
# 4                      2707               325                 746
#
#                  5              6
# 0  Туберку- лезные  Инфекци-онные
# 1            83811          73792
# 2            18312          17991
# 3              605            708
# ...

# %%
bed_fund_2009.columns = list(bed_fund_2009.iloc[0])

bed_fund_2009 = bed_fund_2009.drop(index = 0)

bed_fund_2009.columns = bed_fund_2009.columns.fillna('субъект')

bed_fund_2009.columns = [x.replace('-', '') for x in bed_fund_2009.columns]

column = list(bed_fund_2009.columns)

new_column = [i.replace(' ', '') for i in column]

bed_fund_2009.columns = new_column

# %%
bed_fund_2009.insert(0, 'год', '2008')

bed_fund_2009.head()
# Out:
#     год                        субъект Терапевтическогопрофиля  \
# 1  2008           Российская Федерация                  251264
# 2  2008  Центральный федеральный округ                   69055
# 3  2008           Белгородская область                    2486
# 4  2008               Брянская область                    2411
# 5  2008           Владимирская область                    2117
#
#   Хирургическогопрофиля Онкологические Гинекологические Туберкулезные  \
# 1                264559          39018            72725         83811
# 2                 73783          11051            18724         18312
# 3                  2497            365              642           605
# 4                  2707            325              746           820
# 5                  2378            361              515           508
#
#   Инфекционные
# 1        73792
# 2        17991
# 3          708
# 4          670
# 5          659

# %% [markdown]
# #### Данные из папки за 2011 год

# %%
bed_fund_2011
# Out:
#                                 0                           1  \
# 0                             NaN  Терапевтиче- ского профиля
# 1            Российская Федерация                      296103
# 2   Центральный федеральный округ                       80054
# 3            Белгородская область                        2983
# 4                Брянская область                        2725
# ..                            ...                         ...
# 89               Амурская область                        2049
# 90            Магаданская область                         420
# 91            Сахалинская область                        1401
# 92   Еврейская автономная область                         273
# 93     Чукотский автономный округ                         116
#
#                            2                 3                   4  \
# 0   Хирургиче- ского профиля  Онкологи- ческие  Гинеколо- гические
# 1                     257185             39718               68779
# ...

# %%
bed_fund_2011.columns = list(bed_fund_2011.iloc[0])

bed_fund_2011 = bed_fund_2011.drop(index = 0)

bed_fund_2011.columns = bed_fund_2011.columns.fillna('субъект')

bed_fund_2011.columns = [x.replace('-', '') for x in bed_fund_2011.columns]

column = list(bed_fund_2011.columns)

new_column = [i.replace(' ', '') for i in column]

bed_fund_2011.columns = new_column

# %%
bed_fund_2011.insert(0, 'год', '2010')

bed_fund_2011.head()
# Out:
#     год                        субъект Терапевтическогопрофиля  \
# 1  2010           Российская Федерация                  296103
# 2  2010  Центральный федеральный округ                   80054
# 3  2010           Белгородская область                    2983
# 4  2010               Брянская область                    2725
# 5  2010           Владимирская область                    2560
#
#   Хирургическогопрофиля Онкологические Гинекологические Туберкулезные  \
# 1                257185          39718            68779         83957
# 2                 71244          11277            17369         17815
# 3                  2493            400              601           575
# 4                  2542            325              652           585
# 5                  2264            368              499           453
#
#   Инфекционные
# 1        70530
# 2        16752
# 3          690
# 4          534
# 5          581

# %% [markdown]
# #### Данные из папки за 2013 год

# %%
bed_fund_2013.head()
# Out:
#                         Unnamed: 0  Терапевтического\nпрофиля  \
# 0             Российская Федерация                     302797
# 1  Центральный \nфедеральный округ                      82632
# 2             Белгородская область                       3133
# 3                 Брянская область                       2787
# 4             Владимирская область                       2823
#
#    Хирургического\nпрофиля  Онкологические   Гинеколо-\nгические \n\n\n  \
# 0                    256388           42755                       64646
# 1                     70263           12626                       16420
# 2                      2471             405                         585
# 3                      2466             325                         616
# 4                      2352             367                         502
#
#    Туберкулезные  Инфекци-онные  Офтальмологические  Отоларингологические   \
# 0          93188           70246               23730                 20169
# ...

# %% [markdown]
# Для начала удалим символ "\n" в названиях колонок датафрейма

# %%
bed_fund_2013.columns = [x.replace('\n',' ') for x in bed_fund_2013.columns]

# %% [markdown]
# Теперь удалим все тире между названиями колонок

# %%
bed_fund_2013.columns = [x.replace('-', '') for x in bed_fund_2013.columns]

# %% [markdown]
# Теперь удалим все пробелы в названиях колонок

# %%
column = list(bed_fund_2013.columns)

new_column = [i.replace(' ', '') for i in column]

bed_fund_2013.columns = new_column

# %%
bed_fund_2013 = bed_fund_2013.rename(columns={'Unnamed:0':'субъект'})

bed_fund_2013.head()
# Out:
#                            субъект  Терапевтическогопрофиля  \
# 0             Российская Федерация                   302797
# 1  Центральный \nфедеральный округ                    82632
# 2             Белгородская область                     3133
# 3                 Брянская область                     2787
# 4             Владимирская область                     2823
#
#    Хирургическогопрофиля Онкологические  Гинекологические  Туберкулезные  \
# 0                 256388          42755             64646          93188
# 1                  70263          12626             16420          18315
# 2                   2471            405               585            600
# 3                   2466            325               616            739
# 4                   2352            367               502            826
#
#    Инфекционные Офтальмологические Отоларингологические  \
# 0         70246              23730                20169
# ...

# %% [markdown]
# Теперь удалим символ '\n' во всем датафрейме

# %%
bed_fund_2013 = bed_fund_2013.replace(r'\n', '', regex=True)

# %%
bed_fund_2013.insert(0, 'год', '2012')

bed_fund_2013.head()
# Out:
#     год                        субъект  Терапевтическогопрофиля  \
# 0  2012           Российская Федерация                   302797
# 1  2012  Центральный федеральный округ                    82632
# 2  2012           Белгородская область                     3133
# 3  2012               Брянская область                     2787
# 4  2012           Владимирская область                     2823
#
#    Хирургическогопрофиля Онкологические  Гинекологические  Туберкулезные  \
# 0                 256388          42755             64646          93188
# 1                  70263          12626             16420          18315
# 2                   2471            405               585            600
# 3                   2466            325               616            739
# 4                   2352            367               502            826
#
#    Инфекционные Офтальмологические Отоларингологические  \
# 0         70246              23730                20169
# ...

# %% [markdown]
# ### Сохранение данных

# %%
bed_fund_2005.to_csv('bed_fund_2005.csv')

# %%
bed_fund_2007.to_csv('bed_fund_2007.csv')

# %%
bed_fund_2009.to_csv('bed_fund_2009.csv')

# %%
bed_fund_2011.to_csv('bed_fund_2011.csv')

# %%
bed_fund_2013.to_csv('bed_fund_2013.csv')

# %% [markdown]
# ### Дополнительное соединение и сохранение датасета

# %% [markdown]
# Соединение всеx таблиц "снизу"

# %%
s = pd.concat([bed_fund_2005, bed_fund_2007], axis=0)

# %%
s_1 = pd.concat([s, bed_fund_2009], axis=0)

# %%
s_2 = pd.concat([s_1, bed_fund_2011], axis=0)

# %%
s_3 = pd.concat([s_2, bed_fund_2013], axis=0)

# %% [markdown]
# Сохраним итоговую таблицы в датасет с названием test_3

# %%
s_3.to_csv('test_3.csv')

# %% [markdown]
# ### Ссылка на дашборд

# %% [markdown]
# Дашборд выполнен в программе Tableau и доступен по [ссылке](https://public.tableau.com/views/bed_fund_corrected/sheet4?:language=en-US&:sid=&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# За период 2004 - 2012:
# - кол-во инфекционных коек:
#     - по федеральным округам кол-во коек уменьшилось в 1,9 раза;
#     - по областям кол-во коек уменьшилось в 2,9 раза;
#     - по республикам кол-во коек уменьшилось в 3 раза;
#     - по 2 городам федерального значения (Москва и СПб) кол-во коек уменьшилось в 1,06 раза;
#     - по автономным округам кол-во коек уменьшилось в 1,2 раза.
# - кол-во онкологических коек:
#     - по федеральным округам кол-во коек уменьшилось в 1,3 раза;
#     - по областям кол-во коек уменьшилось в 1,9 раза;
#     - по республикам кол-во коек уменьшилось в 3,1 раза;
#     - по 2 городам федерального значения (Москва и СПб) кол-во коек **увеличилось** в 1,2 раза;
#     - по автономным округам кол-во коек **увеличилось** в 1.08 раза.
# - кол-во коек для беременных, рожениц и родильниц:
#     - по федеральным округам кол-во коек уменьшилось в 1.7 раза;
#     - по областям кол-во коек уменьшилось в 2,5 раза;
#     - по республикам кол-во коек уменьшилось в 2,4 раза;
#     - по 2 городам федерального значения (Москва и СПб) кол-во коек уменьшилось в 1.022 раза;
#     - по автономным округам данных недостаточно.
#
# При этом количество амбулаторных медицинских организаций (поликлиник) уменьшилось на 6%.

# %% [markdown]
# ## Техническое состояние и благоустройство зданий лечебно-профилактических учреждений здравоохранения. Ресурсы и деятельность организаций здравоохранения.

# %% [markdown]
# ### Предположение

# %% [markdown]
# За период 1990 - 2022 какова динамика снижения процентного соотношения зданий больниц в которых отсутствует водопровод, горячее водоснабжение, центральное отопление, канализация, телефонная связь?

# %% [markdown]
# ### Загрузка данных

# %%
technical_condition_2005 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2005/Ресурсы и деятельность учреждений здравоохранения/техническое состояние и благоустройство зданий лечебно-профилактических учреждений здравоохранения.csv')

technical_condition_2005
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Всего зданий, тыс.
# 3   в том числе по техническому состоянию, процентов:
# 4                     находятся в аварийном состоянии
# 5                               требуют реконструкции
# 6                        требуют капитального ремонта
# 7   Удельный вес числа зданий, в которых отсутству...
# 8                                          водопровод
# 9                               горячее водоснабжение
# 10                              центральное отопление
# 11                                        канализация
# 12                                   телефонная связь
# 13                                                NaN
# 14                                 Всего зданий, тыс.
# 15  в том числе по техническому состоянию, процентов:
# ...

# %%
technical_condition_2007 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2007/Ресурсы и деятельность учреждений здравоохранения/техническое состояние и благоустройство зданий лечебно - профилактических учреждений здравоохранения.csv')

technical_condition_2007
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Всего зданий, тыс.
# 3   в том числе по техническому состоянию,  процен...
# 4                     находятся в аварийном состоянии
# 5                               требуют реконструкции
# 6                        требуют капитального ремонта
# 7   Удельный вес числа зданий, в которых отсутству...
# 8                                          водопровод
# 9                               горячее водоснабжение
# 10                              центральное отопление
# 11                                        канализация
# 12                                   телефонная связь
# 13                                                NaN
# 14                                 Всего зданий, тыс.
# 15  в том числе по техническому состоянию,  процен...
# ...

# %%
technical_condition_2009 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2009/Ресурсы и деятельность учреждений здравоохранения/техническое состояние и благоустройство зданий лечебно- профилактических учреждений здравоохранения.csv')

technical_condition_2009
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Всего зданий, тыс.
# 3        из них по техническому состоянию, процентов:
# 4                     находятся в аварийном состоянии
# 5                               требуют реконструкции
# 6                        требуют капитального ремонта
# 7   Удельный вес числа зданий, в которых отсутству...
# 8                                          водопровод
# 9                               горячее водоснабжение
# 10                              центральное отопление
# 11                                        канализация
# 12                                   телефонная связь
# 13                                                NaN
# 14                                 Всего зданий, тыс.
# 15       из них по техническому состоянию, процентов:
# ...

# %%
technical_condition_2011 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2011/Ресурсы и деятельность учреждений здравоохранения/техническое состояние и благоустройство зданий лечебно-профилактических учреждений здравоохранения.csv')

technical_condition_2011
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Всего зданий, тыс.
# 3        из них по техническому состоянию, процентов:
# 4                     находятся в аварийном состоянии
# 5                               требуют реконструкции
# 6                        требуют капитального ремонта
# 7   Удельный вес числа зданий, в которых отсутству...
# 8                                          водопровод
# 9                               горячее водоснабжение
# 10                              центральное отопление
# 11                                        канализация
# 12                                   телефонная связь
# 13                                                NaN
# 14                                 Всего зданий, тыс.
# 15       из них по техническому состоянию, процентов:
# ...

# %%
technical_condition_2013 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2013/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.10. техническое состояние и благоустройство зданий  лечебно-профилактических организаций здравоохранения1).csv')

technical_condition_2013
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2      из них по техническому состоянию, \nпроцентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14     из них по техническому состоянию, \nпроцентов:
# 15                    находятся в аварийном состоянии
# ...

# %%
technical_condition_2015 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2015/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.10. техническое состояние и благоустройство зданий  лечебно-профилактических организаций здравоохранения1).csv')

technical_condition_2015
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2      из них по техническому состоянию, \nпроцентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14     из них по техническому состоянию, \nпроцентов:
# 15                    находятся в аварийном состоянии
# ...

# %%
technical_condition_2017 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2017/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.12. техническое состояние и благоустройство зданий  лечебно-профилактических организаций здравоохранения1).csv')

technical_condition_2017
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2        из них по техническому состоянию, процентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14       из них по техническому состоянию, процентов:
# 15                    находятся в аварийном состоянии
# ...

# %%
technical_condition_2019 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2019/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.12. техническое состояние и благоустройство зданий  лечебно-профилактических организаций здравоохранения1).csv')

technical_condition_2019
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2        из них по техническому состоянию, процентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14       из них по техническому состоянию, процентов:
# 15                    находятся в аварийном состоянии
# ...

# %%
technical_condition_2021 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2021/РЕСУРСЫ И ДЕЯТЕЛЬНОСТЬ ОРГАНИЗАЦИЙ /3.12. техническое состояние и благоустройство зданий  медицинских организаций здравоохранения1).csv')

technical_condition_2021
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2        из них по техническому состоянию, процентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14       из них по техническому состоянию, процентов:
# 15                    находятся в аварийном состоянии
# ...

# %%
technical_condition_2023 = pd.read_csv('/Users/mac/Desktop/проекты в Яндекс Практикуме/Датасеты и проекты/Мастерская/данные/2023/3.12. ТЕХНИЧЕСКОЕ СОСТОЯНИЕ И БЛАГОУСТРОЙСТВО ЗДАНИЙ МЕДИЦИНСКИХ ОРГАНИЗАЦИЙ ЗДРАВООХРАНЕНИЯ1) - 3.12.csv')

technical_condition_2023
# Out:
#    3.12. ТЕХНИЧЕСКОЕ СОСТОЯНИЕ И БЛАГОУСТРОЙСТВО ЗДАНИЙ МЕДИЦИНСКИХ ОРГАНИЗАЦИЙ ЗДРАВООХРАНЕНИЯ1)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Всего зданий, тыс.
# 3        из них по техническому состоянию, процентов:
# 4                     находятся в аварийном состоянии
# 5                               требуют реконструкции
# 6                        требуют капитального ремонта
# 7   Удельный вес числа зданий, в которых отсутству...
# 8                                          водопровод
# 9                               горячее водоснабжение
# 10                              центральное отопление
# 11                                        канализация
# 12                                   телефонная связь
# 13                                                NaN
# 14                                 Всего зданий, тыс.
# 15       из них по техническому состоянию, процентов:
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Возьмем первую строку датафрейма и сделаем из неё название колонок и потом сразу удалим её. Для этого напишем функцию и передадим ей датафреймы по очереди вплоть до 2011 года и для 2023 года тоже.

# %%
def column_new(data):
    data.columns = list(data.iloc[0])
    data = data.drop(index = 0).reset_index(drop=True)
    data.rename(columns = {np.nan:'name'}, inplace=True)
    return data

# %%
technical_condition_2005 = column_new(technical_condition_2005)

# %%
technical_condition_2007 = column_new(technical_condition_2007)

# %%
technical_condition_2009 = column_new(technical_condition_2009)

# %%
technical_condition_2011 = column_new(technical_condition_2011)

# %%
technical_condition_2023 = column_new(technical_condition_2023)

# %% [markdown]
# С датафреймами из папок с 2013 по 2021 изменим названия 1 колонки с `Unnamed: 0	` на `name` с целью дальнейшего корректного соединения.

# %%
technical_condition_2013.rename(columns={'Unnamed: 0':'name'}, inplace=True)

technical_condition_2015.rename(columns={'Unnamed: 0':'name'}, inplace=True)

technical_condition_2017.rename(columns={'Unnamed: 0':'name'}, inplace=True)

technical_condition_2019.rename(columns={'Unnamed: 0':'name'}, inplace=True)

technical_condition_2021.rename(columns={'Unnamed: 0':'name'}, inplace=True)

# %% [markdown]
# Создадим список датафреймов и проверим их длину

# %%
t = [technical_condition_2007, 
     technical_condition_2009,
    technical_condition_2011,
    technical_condition_2013,
    technical_condition_2015,
    technical_condition_2017,
    technical_condition_2019,
    technical_condition_2021,
    technical_condition_2023]

# %%
for el in t:
    print(len(el))
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %% [markdown]
# Все получившиеся датафреймы имеют одинаковую длину и для унификации строк с индексами 0 и 12 создадим список и передадим его каждому датафрейму. За образец возьмём названия этих строк по индексам за 2005-2009 года, так как они кажутся наиболее полными.

# %% [markdown]
# Напишем функцию, которая будет прпнимать датафрейм и шаблонный датафрейм (для названия колонок) из папки 2005 года и вернёт изменённые строки с индексами 0 и 12 на унифицированные. Также в этой функции предусмотрим изменение название колонки `name` во всех датасетах на наименования из колонки `name` шаблонного датафрейма (опять же с целью унификации названий и дальнейшего соединения).

# %%
technical_condition_2009.columns
# Out:
# Index(['name', '1995', '2001', '2003', '2007', '2008'], dtype='object')

# %%
def row_new(data, data_pattern):
    mask_row_0 = data_pattern['1995'].values[0]
    
    mask_row_12 = data_pattern['1995'].values[12]
    
    data.iloc[0,1:] = mask_row_0
    
    data.iloc[12,1:] = mask_row_12
    
    mask_column = data_pattern['name']
    
    data['name'] = mask_column
    
    return data

# %% [markdown]
# Теперь вновь написанной функции передадим все данные из папок с 2005 по 2023

# %%
с = row_new(technical_condition_2007, technical_condition_2005)

technical_condition_2009 = row_new(technical_condition_2009, technical_condition_2005)

technical_condition_2011 = row_new(technical_condition_2011, technical_condition_2005)

technical_condition_2013 = row_new(technical_condition_2013, technical_condition_2005)

technical_condition_2015 = row_new(technical_condition_2015, technical_condition_2005)

technical_condition_2017 = row_new(technical_condition_2017, technical_condition_2005)

technical_condition_2019 = row_new(technical_condition_2019, technical_condition_2005)

technical_condition_2021 = row_new(technical_condition_2021, technical_condition_2005)

technical_condition_2023 = row_new(technical_condition_2023, technical_condition_2005)

# %% [markdown]
# ### Соединение в единый датасет

# %% [markdown]
# Соединими все таблицы в единый датасет

# %%
technical_condition_1 = pd.concat([technical_condition_2005, technical_condition_2007], axis=1)

# %%
technical_condition_2 = pd.concat([technical_condition_1, technical_condition_2009], axis=1)

# %%
technical_condition_3 = pd.concat([technical_condition_2, technical_condition_2011], axis=1)

# %%
technical_condition_4 = pd.concat([technical_condition_3, technical_condition_2013], axis=1)

# %%
technical_condition_5 = pd.concat([technical_condition_4, technical_condition_2015], axis=1)

# %%
technical_condition_6 = pd.concat([technical_condition_5, technical_condition_2017], axis=1)

# %%
technical_condition_7 = pd.concat([technical_condition_6, technical_condition_2019], axis=1)

# %%
technical_condition_8 = pd.concat([technical_condition_7, technical_condition_2021], axis=1)

# %%
technical_condition_total = pd.concat([technical_condition_8, technical_condition_2023], axis=1)

# %% [markdown]
# Теперь удалим дублирующиеся столбцы по наименванию года

# %%
technical_condition_total = technical_condition_total.loc[:,~technical_condition_total.columns.duplicated()].copy()

technical_condition_total
# Out:
#                                                  name  \
# 0                                                 NaN
# 1                                  Всего зданий, тыс.
# 2   в том числе по техническому состоянию, процентов:
# 3                     находятся в аварийном состоянии
# 4                               требуют реконструкции
# 5                        требуют капитального ремонта
# 6   Удельный вес числа зданий, в которых отсутству...
# 7                                          водопровод
# 8                               горячее водоснабжение
# 9                               центральное отопление
# 10                                        канализация
# 11                                   телефонная связь
# 12                                                NaN
# 13                                 Всего зданий, тыс.
# 14  в том числе по техническому состоянию, процентов:
# 15                    находятся в аварийном состоянии
# ...

# %% [markdown]
# ### Сохранение получившихся датасетов и разделение их на стационар и амбулатории

# %% [markdown]
# Из исходного датафрейма сохраним стационарные учреждения в один датасет, а амбулаторные учреждения в другой датасет

# %% [markdown]
# Стационарные учреждения - technical_condition_hospital

# %%
technical_condition_hospital = technical_condition_total.iloc[:12,:].copy()

technical_condition_hospital.drop(index=0, inplace=True)

technical_condition_hospital
# Out:
#                                                  name  1995  2001  2003  2006  \
# 1                                  Всего зданий, тыс.  27.0  24.8  23.8  23.2
# 2   в том числе по техническому состоянию, процентов:   NaN   NaN   NaN   NaN
# 3                     находятся в аварийном состоянии   5.2   3.4   3.3   3.7
# 4                               требуют реконструкции   7.7   6.1   6.4   6.2
# 5                        требуют капитального ремонта  31.9  29.6  28.5  27.9
# 6   Удельный вес числа зданий, в которых отсутству...   NaN   NaN   NaN   NaN
# 7                                          водопровод  13.2  10.8   8.8   8.9
# 8                               горячее водоснабжение  39.5  35.5  33.1  31.7
# 9                               центральное отопление  14.7  10.1   9.6   9.4
# 10                                        канализация  18.7  13.2  12.2  11.3
# 11                                   телефонная связь  10.5   9.9   7.7   7.5
#
# ...

# %% [markdown]
# Амбулаторные учреждения - technical_condition_outpatient_clinic

# %%
technical_condition_outpatient_clinic = technical_condition_total.iloc[12:,:].copy()

technical_condition_outpatient_clinic.reset_index(drop=True, inplace=True)

technical_condition_outpatient_clinic.drop(index=0, inplace=True)

# %%
technical_condition_outpatient_clinic
# Out:
#                                                  name  1995  2001  2003  2006  \
# 1                                  Всего зданий, тыс.  19.7  19.9  20.0  19.5
# 2   в том числе по техническому состоянию, процентов:   NaN   NaN   NaN   NaN
# 3                     находятся в аварийном состоянии   3.6   2.0   1.6   1.6
# 4                               требуют реконструкции   5.5   4.8   4.8   4.2
# 5                        требуют капитального ремонта  27.4  25.0  24.0  23.1
# 6   Удельный вес числа зданий, в которых отсутству...   NaN   NaN   NaN   NaN
# 7                                          водопровод  15.9  13.1  13.8  13.0
# 8                               горячее водоснабжение  44.1  42.9  42.3  40.0
# 9                               центральное отопление  16.3  14.3  14.4  14.2
# 10                                        канализация  22.6  18.2  17.9  16.7
# 11                                   телефонная связь   9.0   8.7   9.8  10.2
#
# ...

# %% [markdown]
# Для корректной работы с данными при визуализации, изменим все символы запятых на точки. Основная цель этих изменений - запятые между цифрами.

# %%
technical_condition_hospital = technical_condition_hospital.apply(lambda x: x.str.replace(',', '.'))

technical_condition_outpatient_clinic = technical_condition_outpatient_clinic.apply(lambda x: 
                                                                                    x.str.replace(',', '.'))

# %% [markdown]
# Транспонируем датасеты и сохраняем для дальнейшей их визуализации и построение дашбордов.

# %%
technical_condition_hospital = technical_condition_hospital.set_index('name').T

# %%
technical_condition_outpatient_clinic = technical_condition_outpatient_clinic.set_index('name').T

# %%
technical_condition_hospital.to_csv('technical_condition_hospital.csv')

# %%
technical_condition_outpatient_clinic.to_csv('technical_condition_outpatient_clinic.csv')

# %% [markdown]
# ### Ссылка на дашборд

# %% [markdown]
# Дашборд выполнен в программе Tableau и доступен по [ссылке](https://public.tableau.com/views/technical_condition_hospital/sheet13?:language=en-US&:sid=&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# Стационарные медицинские учреждения и динамика % соотношения:
#
# - % отсутствия горячего водоснабжения снизился на 23,6%;
# - % отсутствия канализации снизился на 14,6%;
# - % отсутствия центрального отопления снизился на 5,8%;
# - % отсутствия водопровода снизился на 10,4%;
# - % отсутствия телефонной связи снизился на 5,4%.
#
# Амбулаторные медицинские учреждения и динамика % соотношения:
#
# - % отсутствия горячего водоснабжения снизился на 19,8%;
# - % отсутствия канализации снизился на 16,7%;
# - % отсутствия центрального отопления снизился на 2,1%;
# - % отсутствия водопровода снизился на 12%;
# - % отсутствия телефонной связи снизился на 4%.
